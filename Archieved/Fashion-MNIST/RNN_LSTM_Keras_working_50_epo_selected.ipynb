# %%
# !mkdir models3

# %%
# !ls

# %%
# %matplotlib inline

from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras import optimizers

from keras.models import Model
from keras.layers import Input, Dense, TimeDistributed, LSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

import cv2
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


def img_resize(org_imgs, target_size):
  x_imgs = []
  for i in range(0,org_imgs.shape[0]):
    x_img = cv2.resize(org_imgs[i], dsize=(target_size, target_size), interpolation=cv2.INTER_CUBIC)
    x_imgs.append(x_img)
  return np.array(x_imgs)


def plot_model(model_details):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_details.history['loss'])+1),model_details.history['loss'])
    axs[1].plot(range(1,len(model_details.history['val_loss'])+1),model_details.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_details.history['loss'])+1),len(model_details.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_details.history['acc'])+1),model_details.history['acc'])
    axs[0].plot(range(1,len(model_details.history['val_acc'])+1),model_details.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_details.history['acc'])+1),len(model_details.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()
    
    
# Training parameters.
batch_sizes = [64]
num_epochs = [50]
learning_rates = [0.0001,0.001]
optimizers_name = ['rmsprop', 'adam']
num_classes = 10
node_sizes = [32]

# The data, shuffled and split between train and test sets.
(images, labels), (_, _) = fashion_mnist.load_data()

images_zoomed_in = img_resize(images, 48)
images_zoomed_in = images_zoomed_in.reshape(images_zoomed_in.shape[0], images_zoomed_in.shape[1], images_zoomed_in.shape[2], 1).astype('float32')

x_train = images_zoomed_in[0:50000]
x_test = images_zoomed_in[50000:60000]

y_train = labels[0:50000]
y_test = labels[50000:60000]


# x_train -= np.mean(x_train)
# x_test -= np.mean(x_train)

# x_train /= np.std(x_train)
# x_test /= np.std(x_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


TRAIN_DATA_SIZE = x_train.shape[0]
TEST_DATA_SIZE = x_test.shape[0]

#TRAIN_BATCH_SIZE = 20
#TEST_BATCH_SIZE = 10

#train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
#test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)


# Converts class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

train_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
train_gen.fit(x_train)
#train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

test_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
test_gen.fit(x_train)
#test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

#row, col, pixel = x_train.shape[1:]


best_model = None
best_accuracy = 0
best_batch_size = 0
best_epochs = 0
best_optimizer = ''
best_learning_rate = 0
best_node_size = 0
# Out:
# /home/ryantsan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (50000, 48, 48, 1)
# 50000 train samples
# 10000 test samples

# %%
for batch_size in batch_sizes:
  for epochs in num_epochs:
    for optimizer_name in optimizers_name:
      for learning_rate in learning_rates:
        for node_size in node_sizes:
            print("==================")
            print("batch size    : {}".format(batch_size))
            print("epochs        : {}".format(epochs))
            print("optimizer     : {}".format(optimizer_name))
            print("learning rate : {}".format(learning_rate))
            print("node size     : {}".format(node_size))

            if optimizer_name == 'adam':
              optimizer = optimizers.Adam(lr=learning_rate)
            elif optimizer_name == 'rmsprop':
              optimizer = optimizers.RMSprop(lr=learning_rate)
            elif optimizer_name == 'sgd':
              optimizer = optimizers.SGD(lr=learning_rate)

            # Embedding dimensions.
            row_hidden = node_size
            col_hidden = node_size

            
            TRAIN_BATCH_SIZE = batch_size
            TEST_BATCH_SIZE = (batch_size)
            TEST_BATCH_SIZE
            
            train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
            test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)
            
            train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

            test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

            row, col, pixel = x_train.shape[1:]
            
            
            # 4D input.
            x = Input(shape=(row, col, pixel))

            # Encodes a row of pixels using TimeDistributed Wrapper.
            encoded_rows = TimeDistributed(LSTM(row_hidden))(x)

            # Encodes columns of encoded rows.
            encoded_columns = LSTM(col_hidden)(encoded_rows)

            # Final predictions and model.
            prediction = Dense(num_classes, activation='softmax')(encoded_columns)

            model = Model(x, prediction)
            model.compile(loss='categorical_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])

            


            # Training.
            # model.fit(x_train, y_train,
            #           batch_size=batch_size,
            #           epochs=epochs,
            #           verbose=1,
            #           validation_data=(x_test, y_test))
            
            model_file_name = "models3/rnn_lstm_{}_{}_{}_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size)
            #model_file_name = "models2/rnn_lstm_{}_{}_{}_{}_{}_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size, val_acc, val_loss)
          
            checkpoint = ModelCheckpoint(model_file_name, monitor='val_loss', verbose=1, save_best_only= True, mode='auto')
            #model_file_name = "models2/rnn_lstm_{}_{}_{}_{}_{}_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size,val_acc,val_loss)
            
            best_model_file_name = "models3/rnn_lstm.h5"
            best_checkpoint = ModelCheckpoint(best_model_file_name, monitor='val_loss', verbose=0, save_best_only= True, mode='auto')
       
            h = model.fit_generator(train_batches, steps_per_epoch=train_step, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], validation_steps=test_step, epochs=epochs, verbose=1)
            #h = model.fit_generator(train_batches, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], verbose=1)
  
            plot_model(h)
# Out:
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : rmsprop
# learning rate : 0.0001
# node size     : 32
# Epoch 1/50
# 781/781 [==============================] - 68s 88ms/step - loss: 1.9978 - acc: 0.2878 - val_loss: 1.5760 - val_acc: 0.3974
#
# Epoch 00001: val_loss improved from inf to 1.57596, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 2/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.3407 - acc: 0.4998 - val_loss: 1.1886 - val_acc: 0.5438
#
# Epoch 00002: val_loss improved from 1.57596 to 1.18859, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 3/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.1113 - acc: 0.5858 - val_loss: 1.0609 - val_acc: 0.6076
#
# Epoch 00003: val_loss improved from 1.18859 to 1.06091, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 4/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.0177 - acc: 0.6233 - val_loss: 0.9997 - val_acc: 0.6283
#
# Epoch 00004: val_loss improved from 1.06091 to 0.99970, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 5/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.9631 - acc: 0.6423 - val_loss: 0.9542 - val_acc: 0.6485
#
# Epoch 00005: val_loss improved from 0.99970 to 0.95424, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 6/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.9210 - acc: 0.6560 - val_loss: 0.9101 - val_acc: 0.6668
#
# Epoch 00006: val_loss improved from 0.95424 to 0.91007, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 7/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.8854 - acc: 0.6716 - val_loss: 0.8796 - val_acc: 0.6791
#
# Epoch 00007: val_loss improved from 0.91007 to 0.87960, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 8/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.8497 - acc: 0.6870 - val_loss: 0.8445 - val_acc: 0.7017
#
# Epoch 00008: val_loss improved from 0.87960 to 0.84451, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 9/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.8118 - acc: 0.7080 - val_loss: 0.8128 - val_acc: 0.7174
#
# Epoch 00009: val_loss improved from 0.84451 to 0.81280, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 10/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7772 - acc: 0.7202 - val_loss: 0.7848 - val_acc: 0.7181
#
# Epoch 00010: val_loss improved from 0.81280 to 0.78481, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 11/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7453 - acc: 0.7305 - val_loss: 0.7444 - val_acc: 0.7329
#
# Epoch 00011: val_loss improved from 0.78481 to 0.74444, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 12/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7162 - acc: 0.7424 - val_loss: 0.7166 - val_acc: 0.7457
#
# Epoch 00012: val_loss improved from 0.74444 to 0.71661, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 13/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6856 - acc: 0.7542 - val_loss: 0.6942 - val_acc: 0.7549
#
# Epoch 00013: val_loss improved from 0.71661 to 0.69423, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 14/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6565 - acc: 0.7675 - val_loss: 0.6662 - val_acc: 0.7641
#
# Epoch 00014: val_loss improved from 0.69423 to 0.66623, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 15/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6325 - acc: 0.7764 - val_loss: 0.6351 - val_acc: 0.7770
#
# Epoch 00015: val_loss improved from 0.66623 to 0.63506, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 16/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6089 - acc: 0.7849 - val_loss: 0.6261 - val_acc: 0.7811
#
# Epoch 00016: val_loss improved from 0.63506 to 0.62610, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 17/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5886 - acc: 0.7928 - val_loss: 0.6119 - val_acc: 0.7795
#
# Epoch 00017: val_loss improved from 0.62610 to 0.61186, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 18/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5745 - acc: 0.7957 - val_loss: 0.5806 - val_acc: 0.7948
#
# Epoch 00018: val_loss improved from 0.61186 to 0.58064, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 19/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5597 - acc: 0.8022 - val_loss: 0.5562 - val_acc: 0.8047
#
# Epoch 00019: val_loss improved from 0.58064 to 0.55621, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 20/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5469 - acc: 0.8069 - val_loss: 0.5482 - val_acc: 0.8072
#
# Epoch 00020: val_loss improved from 0.55621 to 0.54824, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 21/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5345 - acc: 0.8110 - val_loss: 0.5385 - val_acc: 0.8103
#
# Epoch 00021: val_loss improved from 0.54824 to 0.53850, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 22/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5246 - acc: 0.8148 - val_loss: 0.5593 - val_acc: 0.8018
#
# Epoch 00022: val_loss did not improve from 0.53850
# Epoch 23/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5141 - acc: 0.8174 - val_loss: 0.5166 - val_acc: 0.8177
#
# Epoch 00023: val_loss improved from 0.53850 to 0.51663, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 24/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5076 - acc: 0.8197 - val_loss: 0.5113 - val_acc: 0.8180
#
# Epoch 00024: val_loss improved from 0.51663 to 0.51126, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 25/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4987 - acc: 0.8220 - val_loss: 0.5035 - val_acc: 0.8204
#
# Epoch 00025: val_loss improved from 0.51126 to 0.50350, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 26/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4935 - acc: 0.8235 - val_loss: 0.4927 - val_acc: 0.8243
#
# Epoch 00026: val_loss improved from 0.50350 to 0.49273, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 27/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4863 - acc: 0.8259 - val_loss: 0.4908 - val_acc: 0.8250
#
# Epoch 00027: val_loss improved from 0.49273 to 0.49083, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 28/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4818 - acc: 0.8265 - val_loss: 0.4917 - val_acc: 0.8252
#
# Epoch 00028: val_loss did not improve from 0.49083
# Epoch 29/50
# 781/781 [==============================] - 66s 85ms/step - loss: 0.4783 - acc: 0.8283 - val_loss: 0.4771 - val_acc: 0.8270
#
# Epoch 00029: val_loss improved from 0.49083 to 0.47710, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 30/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4723 - acc: 0.8299 - val_loss: 0.4746 - val_acc: 0.8322
#
# Epoch 00030: val_loss improved from 0.47710 to 0.47458, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 31/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4661 - acc: 0.8329 - val_loss: 0.4754 - val_acc: 0.8314
#
# Epoch 00031: val_loss did not improve from 0.47458
# Epoch 32/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4649 - acc: 0.8331 - val_loss: 0.4941 - val_acc: 0.8196
#
# Epoch 00032: val_loss did not improve from 0.47458
# Epoch 33/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4589 - acc: 0.8344 - val_loss: 0.4659 - val_acc: 0.8307
#
# Epoch 00033: val_loss improved from 0.47458 to 0.46593, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 34/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4573 - acc: 0.8335 - val_loss: 0.4841 - val_acc: 0.8285
#
# Epoch 00034: val_loss did not improve from 0.46593
# Epoch 35/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4550 - acc: 0.8357 - val_loss: 0.4644 - val_acc: 0.8271
#
# Epoch 00035: val_loss improved from 0.46593 to 0.46439, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 36/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4479 - acc: 0.8377 - val_loss: 0.4608 - val_acc: 0.8343
#
# Epoch 00036: val_loss improved from 0.46439 to 0.46078, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 37/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4483 - acc: 0.8388 - val_loss: 0.4490 - val_acc: 0.8389
#
# Epoch 00037: val_loss improved from 0.46078 to 0.44896, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 38/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4445 - acc: 0.8377 - val_loss: 0.4474 - val_acc: 0.8383
#
# Epoch 00038: val_loss improved from 0.44896 to 0.44743, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 39/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4410 - acc: 0.8404 - val_loss: 0.4643 - val_acc: 0.8316
#
# Epoch 00039: val_loss did not improve from 0.44743
# Epoch 40/50
# 781/781 [==============================] - 66s 85ms/step - loss: 0.4401 - acc: 0.8403 - val_loss: 0.4427 - val_acc: 0.8386
#
# Epoch 00040: val_loss improved from 0.44743 to 0.44268, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 41/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4355 - acc: 0.8418 - val_loss: 0.4545 - val_acc: 0.8361
#
# Epoch 00041: val_loss did not improve from 0.44268
# Epoch 42/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4318 - acc: 0.8427 - val_loss: 0.4426 - val_acc: 0.8402
#
# Epoch 00042: val_loss improved from 0.44268 to 0.44265, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 43/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4318 - acc: 0.8437 - val_loss: 0.4478 - val_acc: 0.8391
#
# Epoch 00043: val_loss did not improve from 0.44265
# Epoch 44/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4278 - acc: 0.8454 - val_loss: 0.4621 - val_acc: 0.8303
#
# Epoch 00044: val_loss did not improve from 0.44265
# Epoch 45/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4275 - acc: 0.8445 - val_loss: 0.4434 - val_acc: 0.8384
#
# Epoch 00045: val_loss did not improve from 0.44265
# Epoch 46/50
# 781/781 [==============================] - 66s 85ms/step - loss: 0.4247 - acc: 0.8447 - val_loss: 0.4308 - val_acc: 0.8441
#
# Epoch 00046: val_loss improved from 0.44265 to 0.43081, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 47/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4206 - acc: 0.8471 - val_loss: 0.4323 - val_acc: 0.8455
#
# Epoch 00047: val_loss did not improve from 0.43081
# Epoch 48/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4195 - acc: 0.8468 - val_loss: 0.4460 - val_acc: 0.8420
#
# Epoch 00048: val_loss did not improve from 0.43081
# Epoch 49/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4165 - acc: 0.8478 - val_loss: 0.4250 - val_acc: 0.8433
#
# Epoch 00049: val_loss improved from 0.43081 to 0.42497, saving model to models3/rnn_lstm_64_50_rmsprop_0.0001_32.h5
# Epoch 50/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4146 - acc: 0.8496 - val_loss: 0.4275 - val_acc: 0.8424
#
# Epoch 00050: val_loss did not improve from 0.42497
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : rmsprop
# learning rate : 0.001
# node size     : 32
# Epoch 1/50
# 781/781 [==============================] - 68s 87ms/step - loss: 1.1261 - acc: 0.5751 - val_loss: 0.9075 - val_acc: 0.6638
#
# Epoch 00001: val_loss improved from inf to 0.90745, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 2/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7405 - acc: 0.7317 - val_loss: 0.6140 - val_acc: 0.7891
#
# Epoch 00002: val_loss improved from 0.90745 to 0.61401, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 3/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5986 - acc: 0.7866 - val_loss: 0.5556 - val_acc: 0.7980
#
# Epoch 00003: val_loss improved from 0.61401 to 0.55563, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 4/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5296 - acc: 0.8086 - val_loss: 0.5184 - val_acc: 0.8126
#
# Epoch 00004: val_loss improved from 0.55563 to 0.51845, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 5/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4862 - acc: 0.8245 - val_loss: 0.5128 - val_acc: 0.8180
#
# Epoch 00005: val_loss improved from 0.51845 to 0.51285, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 6/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4567 - acc: 0.8325 - val_loss: 0.4329 - val_acc: 0.8416
#
# Epoch 00006: val_loss improved from 0.51285 to 0.43292, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 7/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4348 - acc: 0.8418 - val_loss: 0.4319 - val_acc: 0.8421
#
# Epoch 00007: val_loss improved from 0.43292 to 0.43186, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 8/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4171 - acc: 0.8480 - val_loss: 0.4788 - val_acc: 0.8239
#
# Epoch 00008: val_loss did not improve from 0.43186
# Epoch 9/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4011 - acc: 0.8535 - val_loss: 0.4046 - val_acc: 0.8534
#
# Epoch 00009: val_loss improved from 0.43186 to 0.40464, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 10/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3869 - acc: 0.8584 - val_loss: 0.3901 - val_acc: 0.8577
#
# Epoch 00010: val_loss improved from 0.40464 to 0.39014, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 11/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3751 - acc: 0.8619 - val_loss: 0.3828 - val_acc: 0.8651
#
# Epoch 00011: val_loss improved from 0.39014 to 0.38277, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 12/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3643 - acc: 0.8658 - val_loss: 0.3712 - val_acc: 0.8660
#
# Epoch 00012: val_loss improved from 0.38277 to 0.37121, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 13/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3559 - acc: 0.8689 - val_loss: 0.3611 - val_acc: 0.8704
#
# Epoch 00013: val_loss improved from 0.37121 to 0.36108, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 14/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3487 - acc: 0.8713 - val_loss: 0.3552 - val_acc: 0.8714
#
# Epoch 00014: val_loss improved from 0.36108 to 0.35521, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 15/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3413 - acc: 0.8734 - val_loss: 0.3607 - val_acc: 0.8704
#
# Epoch 00015: val_loss did not improve from 0.35521
# Epoch 16/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3339 - acc: 0.8766 - val_loss: 0.3456 - val_acc: 0.8755
#
# Epoch 00016: val_loss improved from 0.35521 to 0.34562, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 17/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3274 - acc: 0.8792 - val_loss: 0.3589 - val_acc: 0.8712
#
# Epoch 00017: val_loss did not improve from 0.34562
# Epoch 18/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.3285 - acc: 0.8790 - val_loss: 0.3414 - val_acc: 0.8768
#
# Epoch 00018: val_loss improved from 0.34562 to 0.34140, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 19/50
# 781/781 [==============================] - 70s 89ms/step - loss: 0.3201 - acc: 0.8824 - val_loss: 0.3463 - val_acc: 0.8729
#
# Epoch 00019: val_loss did not improve from 0.34140
# Epoch 20/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.3129 - acc: 0.8857 - val_loss: 0.3428 - val_acc: 0.8782
#
# Epoch 00020: val_loss did not improve from 0.34140
# Epoch 21/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.3097 - acc: 0.8858 - val_loss: 0.3352 - val_acc: 0.8767
#
# Epoch 00021: val_loss improved from 0.34140 to 0.33523, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 22/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.3031 - acc: 0.8884 - val_loss: 0.3447 - val_acc: 0.8740
#
# Epoch 00022: val_loss did not improve from 0.33523
# Epoch 23/50
# 781/781 [==============================] - 68s 88ms/step - loss: 0.3006 - acc: 0.8879 - val_loss: 0.3313 - val_acc: 0.8790
#
# Epoch 00023: val_loss improved from 0.33523 to 0.33132, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 24/50
# 781/781 [==============================] - 68s 88ms/step - loss: 0.2974 - acc: 0.8904 - val_loss: 0.3297 - val_acc: 0.8800
#
# Epoch 00024: val_loss improved from 0.33132 to 0.32973, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 25/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2940 - acc: 0.8905 - val_loss: 0.3284 - val_acc: 0.8797
#
# Epoch 00025: val_loss improved from 0.32973 to 0.32838, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 26/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2900 - acc: 0.8928 - val_loss: 0.3239 - val_acc: 0.8824
#
# Epoch 00026: val_loss improved from 0.32838 to 0.32389, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 27/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2852 - acc: 0.8955 - val_loss: 0.3208 - val_acc: 0.8826
#
# Epoch 00027: val_loss improved from 0.32389 to 0.32084, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 28/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2819 - acc: 0.8958 - val_loss: 0.3228 - val_acc: 0.8832
#
# Epoch 00028: val_loss did not improve from 0.32084
# Epoch 29/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2825 - acc: 0.8971 - val_loss: 0.3208 - val_acc: 0.8820
#
# Epoch 00029: val_loss improved from 0.32084 to 0.32078, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 30/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2764 - acc: 0.8990 - val_loss: 0.3174 - val_acc: 0.8819
#
# Epoch 00030: val_loss improved from 0.32078 to 0.31736, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 31/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2745 - acc: 0.8981 - val_loss: 0.3118 - val_acc: 0.8870
#
# Epoch 00031: val_loss improved from 0.31736 to 0.31183, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 32/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2708 - acc: 0.9003 - val_loss: 0.3128 - val_acc: 0.8878
#
# Epoch 00032: val_loss did not improve from 0.31183
# Epoch 33/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2709 - acc: 0.9012 - val_loss: 0.3112 - val_acc: 0.8868
#
# Epoch 00033: val_loss improved from 0.31183 to 0.31123, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 34/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2667 - acc: 0.9018 - val_loss: 0.3085 - val_acc: 0.8917
#
# Epoch 00034: val_loss improved from 0.31123 to 0.30845, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 35/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2640 - acc: 0.9028 - val_loss: 0.3077 - val_acc: 0.8876
#
# Epoch 00035: val_loss improved from 0.30845 to 0.30766, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 36/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2639 - acc: 0.9028 - val_loss: 0.3133 - val_acc: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.30766
# Epoch 37/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2581 - acc: 0.9044 - val_loss: 0.3058 - val_acc: 0.8902
#
# Epoch 00037: val_loss improved from 0.30766 to 0.30583, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 38/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2611 - acc: 0.9028 - val_loss: 0.3026 - val_acc: 0.8928
#
# Epoch 00038: val_loss improved from 0.30583 to 0.30256, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 39/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2550 - acc: 0.9062 - val_loss: 0.2997 - val_acc: 0.8927
#
# Epoch 00039: val_loss improved from 0.30256 to 0.29969, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 40/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2529 - acc: 0.9070 - val_loss: 0.3106 - val_acc: 0.8902
#
# Epoch 00040: val_loss did not improve from 0.29969
# Epoch 41/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2515 - acc: 0.9069 - val_loss: 0.3043 - val_acc: 0.8896
#
# Epoch 00041: val_loss did not improve from 0.29969
# Epoch 42/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2517 - acc: 0.9087 - val_loss: 0.3100 - val_acc: 0.8891
#
# Epoch 00042: val_loss did not improve from 0.29969
# Epoch 43/50
# 781/781 [==============================] - 68s 87ms/step - loss: 0.2484 - acc: 0.9079 - val_loss: 0.3082 - val_acc: 0.8881
#
# Epoch 00043: val_loss did not improve from 0.29969
# Epoch 44/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2429 - acc: 0.9098 - val_loss: 0.2912 - val_acc: 0.8970
#
# Epoch 00044: val_loss improved from 0.29969 to 0.29121, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 45/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2452 - acc: 0.9103 - val_loss: 0.3122 - val_acc: 0.8908
#
# Epoch 00045: val_loss did not improve from 0.29121
# Epoch 46/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2433 - acc: 0.9103 - val_loss: 0.2971 - val_acc: 0.8960
#
# Epoch 00046: val_loss did not improve from 0.29121
# Epoch 47/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2428 - acc: 0.9105 - val_loss: 0.2907 - val_acc: 0.8943
#
# Epoch 00047: val_loss improved from 0.29121 to 0.29071, saving model to models3/rnn_lstm_64_50_rmsprop_0.001_32.h5
# Epoch 48/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2375 - acc: 0.9122 - val_loss: 0.3035 - val_acc: 0.8923
#
# Epoch 00048: val_loss did not improve from 0.29071
# Epoch 49/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2367 - acc: 0.9127 - val_loss: 0.3244 - val_acc: 0.8849
#
# Epoch 00049: val_loss did not improve from 0.29071
# Epoch 50/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2442 - acc: 0.9094 - val_loss: 0.2960 - val_acc: 0.8968
#
# Epoch 00050: val_loss did not improve from 0.29071
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : adam
# learning rate : 0.0001
# node size     : 32
# Epoch 1/50
# 781/781 [==============================] - 68s 87ms/step - loss: 1.7673 - acc: 0.3415 - val_loss: 1.2951 - val_acc: 0.4951
#
# Epoch 00001: val_loss improved from inf to 1.29515, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 2/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.1540 - acc: 0.5560 - val_loss: 1.0644 - val_acc: 0.5940
#
# Epoch 00002: val_loss improved from 1.29515 to 1.06445, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 3/50
# 781/781 [==============================] - 67s 86ms/step - loss: 1.0135 - acc: 0.6097 - val_loss: 0.9800 - val_acc: 0.6216
#
# Epoch 00003: val_loss improved from 1.06445 to 0.98002, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 4/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.9457 - acc: 0.6381 - val_loss: 0.9659 - val_acc: 0.6267
#
# Epoch 00004: val_loss improved from 0.98002 to 0.96593, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 5/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.9025 - acc: 0.6572 - val_loss: 0.8900 - val_acc: 0.6633
#
# Epoch 00005: val_loss improved from 0.96593 to 0.89002, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 6/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.8668 - acc: 0.6720 - val_loss: 0.8732 - val_acc: 0.6733
#
# Epoch 00006: val_loss improved from 0.89002 to 0.87324, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 7/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.8303 - acc: 0.6931 - val_loss: 0.8150 - val_acc: 0.7020
#
# Epoch 00007: val_loss improved from 0.87324 to 0.81496, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 8/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7694 - acc: 0.7228 - val_loss: 0.7466 - val_acc: 0.7368
#
# Epoch 00008: val_loss improved from 0.81496 to 0.74662, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 9/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7191 - acc: 0.7454 - val_loss: 0.7156 - val_acc: 0.7539
#
# Epoch 00009: val_loss improved from 0.74662 to 0.71563, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 10/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6793 - acc: 0.7599 - val_loss: 0.6813 - val_acc: 0.7624
#
# Epoch 00010: val_loss improved from 0.71563 to 0.68133, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 11/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6528 - acc: 0.7711 - val_loss: 0.6721 - val_acc: 0.7652
#
# Epoch 00011: val_loss improved from 0.68133 to 0.67207, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 12/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6332 - acc: 0.7778 - val_loss: 0.6438 - val_acc: 0.7736
#
# Epoch 00012: val_loss improved from 0.67207 to 0.64378, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 13/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6089 - acc: 0.7866 - val_loss: 0.6091 - val_acc: 0.7852
#
# Epoch 00013: val_loss improved from 0.64378 to 0.60905, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 14/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5929 - acc: 0.7933 - val_loss: 0.5911 - val_acc: 0.7935
#
# Epoch 00014: val_loss improved from 0.60905 to 0.59107, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 15/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5766 - acc: 0.7984 - val_loss: 0.5951 - val_acc: 0.7896
#
# Epoch 00015: val_loss did not improve from 0.59107
# Epoch 16/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5617 - acc: 0.8021 - val_loss: 0.5631 - val_acc: 0.7955
#
# Epoch 00016: val_loss improved from 0.59107 to 0.56312, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 17/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5481 - acc: 0.8054 - val_loss: 0.5639 - val_acc: 0.8019
#
# Epoch 00017: val_loss did not improve from 0.56312
# Epoch 18/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5368 - acc: 0.8100 - val_loss: 0.5490 - val_acc: 0.8042
#
# Epoch 00018: val_loss improved from 0.56312 to 0.54905, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 19/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5276 - acc: 0.8129 - val_loss: 0.5337 - val_acc: 0.8091
#
# Epoch 00019: val_loss improved from 0.54905 to 0.53373, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 20/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5179 - acc: 0.8166 - val_loss: 0.5276 - val_acc: 0.8097
#
# Epoch 00020: val_loss improved from 0.53373 to 0.52757, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 21/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.5074 - acc: 0.8207 - val_loss: 0.5147 - val_acc: 0.8151
#
# Epoch 00021: val_loss improved from 0.52757 to 0.51474, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 22/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4998 - acc: 0.8233 - val_loss: 0.5101 - val_acc: 0.8169
#
# Epoch 00022: val_loss improved from 0.51474 to 0.51012, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 23/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4937 - acc: 0.8249 - val_loss: 0.5002 - val_acc: 0.8202
#
# Epoch 00023: val_loss improved from 0.51012 to 0.50017, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 24/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4894 - acc: 0.8261 - val_loss: 0.4859 - val_acc: 0.8265
#
# Epoch 00024: val_loss improved from 0.50017 to 0.48587, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 25/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4806 - acc: 0.8298 - val_loss: 0.5197 - val_acc: 0.8109
#
# Epoch 00025: val_loss did not improve from 0.48587
# Epoch 26/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4741 - acc: 0.8313 - val_loss: 0.4967 - val_acc: 0.8204
#
# Epoch 00026: val_loss did not improve from 0.48587
# Epoch 27/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4743 - acc: 0.8308 - val_loss: 0.4792 - val_acc: 0.8270
#
# Epoch 00027: val_loss improved from 0.48587 to 0.47919, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 28/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4646 - acc: 0.8324 - val_loss: 0.4748 - val_acc: 0.8276
#
# Epoch 00028: val_loss improved from 0.47919 to 0.47478, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 29/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4611 - acc: 0.8346 - val_loss: 0.4709 - val_acc: 0.8280
#
# Epoch 00029: val_loss improved from 0.47478 to 0.47086, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 30/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4549 - acc: 0.8350 - val_loss: 0.4700 - val_acc: 0.8314
#
# Epoch 00030: val_loss improved from 0.47086 to 0.46999, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 31/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4524 - acc: 0.8379 - val_loss: 0.4566 - val_acc: 0.8351
#
# Epoch 00031: val_loss improved from 0.46999 to 0.45659, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 32/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4486 - acc: 0.8374 - val_loss: 0.4540 - val_acc: 0.8358
#
# Epoch 00032: val_loss improved from 0.45659 to 0.45400, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 33/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4469 - acc: 0.8394 - val_loss: 0.4489 - val_acc: 0.8378
#
# Epoch 00033: val_loss improved from 0.45400 to 0.44894, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 34/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4434 - acc: 0.8396 - val_loss: 0.4495 - val_acc: 0.8387
# Epoch 00034: val_loss did not improve from 0.44894
# Epoch 35/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4531 - acc: 0.8382 - val_loss: 0.4415 - val_acc: 0.8392
#
# Epoch 00035: val_loss improved from 0.44894 to 0.44155, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 36/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4370 - acc: 0.8418 - val_loss: 0.4606 - val_acc: 0.8328
#
# Epoch 00036: val_loss did not improve from 0.44155
# Epoch 37/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4277 - acc: 0.8449 - val_loss: 0.4522 - val_acc: 0.8336
#
# Epoch 00037: val_loss did not improve from 0.44155
# Epoch 38/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4293 - acc: 0.8444 - val_loss: 0.4349 - val_acc: 0.8402
#
# Epoch 00038: val_loss improved from 0.44155 to 0.43486, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 39/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4277 - acc: 0.8444 - val_loss: 0.4483 - val_acc: 0.8372
#
# Epoch 00039: val_loss did not improve from 0.43486
# Epoch 40/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4236 - acc: 0.8460 - val_loss: 0.4286 - val_acc: 0.8423
#
# Epoch 00040: val_loss improved from 0.43486 to 0.42861, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 41/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4230 - acc: 0.8464 - val_loss: 0.4348 - val_acc: 0.8393
#
# Epoch 00041: val_loss did not improve from 0.42861
# Epoch 42/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4377 - acc: 0.8422 - val_loss: 0.4242 - val_acc: 0.8424
#
# Epoch 00042: val_loss improved from 0.42861 to 0.42416, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 43/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4154 - acc: 0.8479 - val_loss: 0.4288 - val_acc: 0.8421
#
# Epoch 00043: val_loss did not improve from 0.42416
# Epoch 44/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4140 - acc: 0.8496 - val_loss: 0.4192 - val_acc: 0.8457
#
# Epoch 00044: val_loss improved from 0.42416 to 0.41915, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 45/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4121 - acc: 0.8496 - val_loss: 0.4206 - val_acc: 0.8464
#
# Epoch 00045: val_loss did not improve from 0.41915
# Epoch 46/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4124 - acc: 0.8490 - val_loss: 0.4260 - val_acc: 0.8422
#
# Epoch 00046: val_loss did not improve from 0.41915
# Epoch 47/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4083 - acc: 0.8510 - val_loss: 0.4185 - val_acc: 0.8481
#
# Epoch 00047: val_loss improved from 0.41915 to 0.41852, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 48/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4051 - acc: 0.8516 - val_loss: 0.4180 - val_acc: 0.8465
#
# Epoch 00048: val_loss improved from 0.41852 to 0.41801, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# Epoch 49/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4047 - acc: 0.8511 - val_loss: 0.4182 - val_acc: 0.8452
#
# Epoch 00049: val_loss did not improve from 0.41801
# Epoch 50/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4039 - acc: 0.8517 - val_loss: 0.4149 - val_acc: 0.8465
#
# Epoch 00050: val_loss improved from 0.41801 to 0.41489, saving model to models3/rnn_lstm_64_50_adam_0.0001_32.h5
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : adam
# learning rate : 0.001
# node size     : 32
# Epoch 1/50
# 781/781 [==============================] - 68s 87ms/step - loss: 1.1458 - acc: 0.5667 - val_loss: 0.8927 - val_acc: 0.6567
#
# Epoch 00001: val_loss improved from inf to 0.89265, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 2/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.7534 - acc: 0.7286 - val_loss: 0.6751 - val_acc: 0.7599
#
# Epoch 00002: val_loss improved from 0.89265 to 0.67509, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 3/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.6141 - acc: 0.7793 - val_loss: 0.5759 - val_acc: 0.7967
#
# Epoch 00003: val_loss improved from 0.67509 to 0.57594, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 4/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.5339 - acc: 0.8070 - val_loss: 0.5150 - val_acc: 0.8135
#
# Epoch 00004: val_loss improved from 0.57594 to 0.51495, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 5/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4916 - acc: 0.8221 - val_loss: 0.4555 - val_acc: 0.8379
#
# Epoch 00005: val_loss improved from 0.51495 to 0.45549, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 6/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4567 - acc: 0.8348 - val_loss: 0.4481 - val_acc: 0.8355
#
# Epoch 00006: val_loss improved from 0.45549 to 0.44810, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 7/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.4377 - acc: 0.8426 - val_loss: 0.5047 - val_acc: 0.8203
#
# Epoch 00007: val_loss did not improve from 0.44810
# Epoch 8/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.4213 - acc: 0.8475 - val_loss: 0.4179 - val_acc: 0.8463
#
# Epoch 00008: val_loss improved from 0.44810 to 0.41789, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 9/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3937 - acc: 0.8553 - val_loss: 0.3944 - val_acc: 0.8538
#
# Epoch 00009: val_loss improved from 0.41789 to 0.39436, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 10/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3847 - acc: 0.8601 - val_loss: 0.3788 - val_acc: 0.8622
#
# Epoch 00010: val_loss improved from 0.39436 to 0.37882, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 11/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3800 - acc: 0.8619 - val_loss: 0.3765 - val_acc: 0.8618
#
# Epoch 00011: val_loss improved from 0.37882 to 0.37648, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 12/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3694 - acc: 0.8637 - val_loss: 0.3701 - val_acc: 0.8644
#
# Epoch 00012: val_loss improved from 0.37648 to 0.37008, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 13/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3728 - acc: 0.8655 - val_loss: 0.3577 - val_acc: 0.8689
#
# Epoch 00013: val_loss improved from 0.37008 to 0.35768, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 14/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3499 - acc: 0.8729 - val_loss: 0.3772 - val_acc: 0.8585
#
# Epoch 00014: val_loss did not improve from 0.35768
# Epoch 15/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3442 - acc: 0.8727 - val_loss: 0.3556 - val_acc: 0.8704
#
# Epoch 00015: val_loss improved from 0.35768 to 0.35560, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 16/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3342 - acc: 0.8782 - val_loss: 0.3588 - val_acc: 0.8678
#
# Epoch 00016: val_loss did not improve from 0.35560
# Epoch 17/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3302 - acc: 0.8794 - val_loss: 0.3504 - val_acc: 0.8732
#
# Epoch 00017: val_loss improved from 0.35560 to 0.35043, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 18/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3232 - acc: 0.8823 - val_loss: 0.3356 - val_acc: 0.8782
#
# Epoch 00018: val_loss improved from 0.35043 to 0.33560, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 19/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3193 - acc: 0.8826 - val_loss: 0.3315 - val_acc: 0.8786
#
# Epoch 00019: val_loss improved from 0.33560 to 0.33146, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 20/50
# 781/781 [==============================] - 67s 85ms/step - loss: 0.3154 - acc: 0.8838 - val_loss: 0.3327 - val_acc: 0.8765
#
# Epoch 00020: val_loss did not improve from 0.33146
# Epoch 21/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3087 - acc: 0.8861 - val_loss: 0.3288 - val_acc: 0.8803
#
# Epoch 00021: val_loss improved from 0.33146 to 0.32877, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 22/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.3059 - acc: 0.8872 - val_loss: 0.3226 - val_acc: 0.8807
#
# Epoch 00022: val_loss improved from 0.32877 to 0.32257, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 23/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2976 - acc: 0.8910 - val_loss: 0.3280 - val_acc: 0.8811
#
# Epoch 00023: val_loss did not improve from 0.32257
# Epoch 24/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2969 - acc: 0.8912 - val_loss: 0.3145 - val_acc: 0.8846
#
# Epoch 00024: val_loss improved from 0.32257 to 0.31447, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 25/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2906 - acc: 0.8944 - val_loss: 0.3442 - val_acc: 0.8728
#
# Epoch 00025: val_loss did not improve from 0.31447
# Epoch 26/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2900 - acc: 0.8927 - val_loss: 0.3195 - val_acc: 0.8838
#
# Epoch 00026: val_loss did not improve from 0.31447
# Epoch 27/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2852 - acc: 0.8953 - val_loss: 0.3272 - val_acc: 0.8826
#
# Epoch 00027: val_loss did not improve from 0.31447
# Epoch 28/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2834 - acc: 0.8957 - val_loss: 0.3189 - val_acc: 0.8857
#
# Epoch 00028: val_loss did not improve from 0.31447
# Epoch 29/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2812 - acc: 0.8956 - val_loss: 0.3576 - val_acc: 0.8712
#
# Epoch 00029: val_loss did not improve from 0.31447
# Epoch 30/50
# 781/781 [==============================] - 67s 86ms/step - loss: 0.2788 - acc: 0.8970 - val_loss: 0.2977 - val_acc: 0.8900
#
# Epoch 00030: val_loss improved from 0.31447 to 0.29770, saving model to models3/rnn_lstm_64_50_adam_0.001_32.h5
# Epoch 31/50
# 127/781 [===>..........................] - ETA: 53s - loss: 0.2591 - acc: 0.9060

# %%
from google.colab import files

print(best_model)
print("Best Stats")
print("==========")
print("accuracy      : {}".format(best_accuracy))
print("batch size    : {}".format(best_batch_size))
print("epochs        : {}".format(best_epochs))
print("optimizer     : {}".format(best_optimizer))
print("learning rate : {}".format(best_learning_rate))
print("node size     : {}".format(best_node_size))

filepath = "models/rnn_lstm_best.h5"
files.download(filepath)
