# %%
# !mkdir models7

# %%
# !ls
# Out:
# models
# models2
# models3
# models4
# models5
# models6
# models7
# RNN_LSTM_Keras_working_35epo_selected.ipynb
# RNN_LSTM_Keras_working_50_epo_adam.ipynb
# RNN_LSTM_Keras_working_50_epo_selected.ipynb
# RNN_LSTM_Keras_working.ipynb
# RNN_LSTM_Keras_working-just_for_50ep_SGD_Momentum_32B.ipynb
# RNN_LSTM_Keras_working-just_for_50ep_SGD_Momentum-Copy1.ipynb
# RNN_LSTM_Keras_working-just_for_50ep_SGD_No_Momentum.ipynb
# RNN_LSTM_Keras_working-just_for_SGD_Momentum.ipynb

# %%
# %matplotlib inline

from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras import optimizers

from keras.models import Model
from keras.layers import Input, Dense, TimeDistributed, LSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

import cv2
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


def img_resize(org_imgs, target_size):
  x_imgs = []
  for i in range(0,org_imgs.shape[0]):
    x_img = cv2.resize(org_imgs[i], dsize=(target_size, target_size), interpolation=cv2.INTER_CUBIC)
    x_imgs.append(x_img)
  return np.array(x_imgs)


def plot_model(model_details):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_details.history['loss'])+1),model_details.history['loss'])
    axs[1].plot(range(1,len(model_details.history['val_loss'])+1),model_details.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_details.history['loss'])+1),len(model_details.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_details.history['acc'])+1),model_details.history['acc'])
    axs[0].plot(range(1,len(model_details.history['val_acc'])+1),model_details.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_details.history['acc'])+1),len(model_details.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()
    
    
# Training parameters.
batch_sizes = [32]
num_epochs = [50]
learning_rates = [0.01,0.05]
optimizers_name = ['sgd']
num_classes = 10
node_sizes = [128]

# The data, shuffled and split between train and test sets.
(images, labels), (_, _) = fashion_mnist.load_data()

images_zoomed_in = img_resize(images, 48)
images_zoomed_in = images_zoomed_in.reshape(images_zoomed_in.shape[0], images_zoomed_in.shape[1], images_zoomed_in.shape[2], 1).astype('float32')

x_train = images_zoomed_in[0:50000]
x_test = images_zoomed_in[50000:60000]

y_train = labels[0:50000]
y_test = labels[50000:60000]


# x_train -= np.mean(x_train)
# x_test -= np.mean(x_train)

# x_train /= np.std(x_train)
# x_test /= np.std(x_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


TRAIN_DATA_SIZE = x_train.shape[0]
TEST_DATA_SIZE = x_test.shape[0]

#TRAIN_BATCH_SIZE = 20
#TEST_BATCH_SIZE = 10

#train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
#test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)


# Converts class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

train_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
train_gen.fit(x_train)
#train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

test_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
test_gen.fit(x_train)
#test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

#row, col, pixel = x_train.shape[1:]


best_model = None
best_accuracy = 0
best_batch_size = 0
best_epochs = 0
best_optimizer = ''
best_learning_rate = 0
best_node_size = 0
# Out:
# /home/ryantsan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (50000, 48, 48, 1)
# 50000 train samples
# 10000 test samples

# %%
for batch_size in batch_sizes:
  for epochs in num_epochs:
    for optimizer_name in optimizers_name:
      for learning_rate in learning_rates:
        for node_size in node_sizes:
            print("==================")
            print("batch size    : {}".format(batch_size))
            print("epochs        : {}".format(epochs))
            print("optimizer     : {}".format(optimizer_name))
            print("learning rate : {}".format(learning_rate))
            print("node size     : {}".format(node_size))

            if optimizer_name == 'adam':
              optimizer = optimizers.Adam(lr=learning_rate)
            elif optimizer_name == 'rmsprop':
              optimizer = optimizers.RMSprop(lr=learning_rate)
            elif optimizer_name == 'sgd':
              optimizer = optimizers.SGD(lr=learning_rate, momentum=0.9,nesterov=True)

            # Embedding dimensions.
            row_hidden = node_size
            col_hidden = node_size

            
            TRAIN_BATCH_SIZE = batch_size
            TEST_BATCH_SIZE = (batch_size)
            TEST_BATCH_SIZE
            
            train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
            test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)
            
            train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

            test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

            row, col, pixel = x_train.shape[1:]
            
            
            # 4D input.
            x = Input(shape=(row, col, pixel))

            # Encodes a row of pixels using TimeDistributed Wrapper.
            encoded_rows = TimeDistributed(LSTM(row_hidden))(x)

            # Encodes columns of encoded rows.
            encoded_columns = LSTM(col_hidden)(encoded_rows)

            # Final predictions and model.
            prediction = Dense(num_classes, activation='softmax')(encoded_columns)

            model = Model(x, prediction)
            model.compile(loss='categorical_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])

            


            # Training.
            # model.fit(x_train, y_train,
            #           batch_size=batch_size,
            #           epochs=epochs,
            #           verbose=1,
            #           validation_data=(x_test, y_test))
            model_file_name = "models7/rnn_lstm_{}_{}_{}NMom_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size)
            checkpoint = ModelCheckpoint(model_file_name, monitor='val_loss', verbose=0, save_best_only= True, mode='auto')

            best_model_file_name = "models7/rnn_lstm.h5"
            best_checkpoint = ModelCheckpoint(best_model_file_name, monitor='val_loss', verbose=1, save_best_only= True, mode='auto')
       
            h = model.fit_generator(train_batches, steps_per_epoch=train_step, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], validation_steps=test_step, epochs=epochs, verbose=1)
            #h = model.fit_generator(train_batches, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], verbose=1)
  
            plot_model(h)
# Out:
# ==================
# batch size    : 32
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.01
# node size     : 128
# Epoch 1/50
# 1562/1562 [==============================] - 139s 89ms/step - loss: 2.0324 - acc: 0.2091 - val_loss: 2.3166 - val_acc: 0.0970
#
# Epoch 00001: val_loss improved from inf to 2.31657, saving model to models7/rnn_lstm.h5
# Epoch 2/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3107 - acc: 0.1018 - val_loss: 2.3081 - val_acc: 0.1023
#
# Epoch 00002: val_loss improved from 2.31657 to 2.30806, saving model to models7/rnn_lstm.h5
# Epoch 3/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3080 - acc: 0.1004 - val_loss: 2.3085 - val_acc: 0.0956
#
# Epoch 00003: val_loss did not improve from 2.30806
# Epoch 4/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3062 - acc: 0.0980 - val_loss: 2.3078 - val_acc: 0.1009
#
# Epoch 00004: val_loss improved from 2.30806 to 2.30777, saving model to models7/rnn_lstm.h5
# Epoch 5/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3051 - acc: 0.1000 - val_loss: 2.3038 - val_acc: 0.1049
#
# Epoch 00005: val_loss improved from 2.30777 to 2.30382, saving model to models7/rnn_lstm.h5
# Epoch 6/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3048 - acc: 0.0985 - val_loss: 2.3027 - val_acc: 0.1049
#
# Epoch 00006: val_loss improved from 2.30382 to 2.30273, saving model to models7/rnn_lstm.h5
# Epoch 7/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3040 - acc: 0.1000 - val_loss: 2.3048 - val_acc: 0.0987
#
# Epoch 00007: val_loss did not improve from 2.30273
# Epoch 8/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3040 - acc: 0.1000 - val_loss: 2.3045 - val_acc: 0.0970
#
# Epoch 00008: val_loss did not improve from 2.30273
# Epoch 9/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3037 - acc: 0.1004 - val_loss: 2.3031 - val_acc: 0.1009
#
# Epoch 00009: val_loss did not improve from 2.30273
# Epoch 10/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3020 - acc: 0.1050 - val_loss: 2.3050 - val_acc: 0.0956
#
# Epoch 00010: val_loss did not improve from 2.30273
# Epoch 11/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.1019 - val_loss: 2.3041 - val_acc: 0.1023
#
# Epoch 00011: val_loss did not improve from 2.30273
# Epoch 12/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3031 - acc: 0.1002 - val_loss: 2.3052 - val_acc: 0.0966
#
# Epoch 00012: val_loss did not improve from 2.30273
# Epoch 13/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3031 - acc: 0.1038 - val_loss: 2.3029 - val_acc: 0.1022
#
# Epoch 00013: val_loss did not improve from 2.30273
# Epoch 14/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3039 - acc: 0.0986 - val_loss: 2.3040 - val_acc: 0.0969
#
# Epoch 00014: val_loss did not improve from 2.30273
# Epoch 15/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3031 - acc: 0.1024 - val_loss: 2.3029 - val_acc: 0.1049
#
# Epoch 00015: val_loss did not improve from 2.30273
# Epoch 16/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3036 - acc: 0.0991 - val_loss: 2.3036 - val_acc: 0.0996
#
# Epoch 00016: val_loss did not improve from 2.30273
# Epoch 17/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.1000 - val_loss: 2.3029 - val_acc: 0.0969
#
# Epoch 00017: val_loss did not improve from 2.30273
# Epoch 18/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3032 - acc: 0.1018 - val_loss: 2.3035 - val_acc: 0.0969
#
# Epoch 00018: val_loss did not improve from 2.30273
# Epoch 19/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0993 - val_loss: 2.3029 - val_acc: 0.0996
#
# Epoch 00019: val_loss did not improve from 2.30273
# Epoch 20/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3035 - acc: 0.1001 - val_loss: 2.3029 - val_acc: 0.1049
#
# Epoch 00020: val_loss did not improve from 2.30273
# Epoch 21/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3031 - acc: 0.1009 - val_loss: 2.3032 - val_acc: 0.1049
#
# Epoch 00021: val_loss did not improve from 2.30273
# Epoch 22/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0996 - val_loss: 2.2885 - val_acc: 0.0969
#
# Epoch 00022: val_loss improved from 2.30273 to 2.28848, saving model to models7/rnn_lstm.h5
# Epoch 23/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.1004 - val_loss: 2.3031 - val_acc: 0.1023
#
# Epoch 00023: val_loss did not improve from 2.28848
# Epoch 24/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.1015 - val_loss: 2.3035 - val_acc: 0.1023
#
# Epoch 00024: val_loss did not improve from 2.28848
# Epoch 25/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3035 - acc: 0.0999 - val_loss: 2.3035 - val_acc: 0.0969
#
# Epoch 00025: val_loss did not improve from 2.28848
# Epoch 26/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0988 - val_loss: 2.3036 - val_acc: 0.0970
#
# Epoch 00026: val_loss did not improve from 2.28848
# Epoch 27/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3031 - acc: 0.0989 - val_loss: 2.2970 - val_acc: 0.1089
#
# Epoch 00027: val_loss did not improve from 2.28848
# Epoch 28/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0992 - val_loss: 2.3027 - val_acc: 0.1009
#
# Epoch 00028: val_loss did not improve from 2.28848
# Epoch 29/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0994 - val_loss: 2.3039 - val_acc: 0.1009
#
# Epoch 00029: val_loss did not improve from 2.28848
# Epoch 30/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0984 - val_loss: 2.3040 - val_acc: 0.0969
#
# Epoch 00030: val_loss did not improve from 2.28848
# Epoch 31/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0983 - val_loss: 2.3029 - val_acc: 0.0970
#
# Epoch 00031: val_loss did not improve from 2.28848
# Epoch 32/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0996 - val_loss: 2.3037 - val_acc: 0.0969
#
# Epoch 00032: val_loss did not improve from 2.28848
# Epoch 33/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3035 - acc: 0.1006 - val_loss: 2.3032 - val_acc: 0.0969
#
# Epoch 00033: val_loss did not improve from 2.28848
# Epoch 34/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3032 - acc: 0.1007 - val_loss: 2.3043 - val_acc: 0.0971
#
# Epoch 00034: val_loss did not improve from 2.28848
# Epoch 35/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0998 - val_loss: 2.3036 - val_acc: 0.0957
#
# Epoch 00035: val_loss did not improve from 2.28848
# Epoch 36/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.1026 - val_loss: 2.3028 - val_acc: 0.1022
#
# Epoch 00036: val_loss did not improve from 2.28848
# Epoch 37/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3004 - acc: 0.1096 - val_loss: 2.2711 - val_acc: 0.1023
#
# Epoch 00037: val_loss improved from 2.28848 to 2.27110, saving model to models7/rnn_lstm.h5
# Epoch 38/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3038 - acc: 0.1012 - val_loss: 2.3040 - val_acc: 0.0987
#
# Epoch 00038: val_loss did not improve from 2.27110
# Epoch 39/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3039 - acc: 0.1018 - val_loss: 2.3036 - val_acc: 0.0956
#
# Epoch 00039: val_loss did not improve from 2.27110
# Epoch 40/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0997 - val_loss: 2.3045 - val_acc: 0.0969
#
# Epoch 00040: val_loss did not improve from 2.27110
# Epoch 41/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3035 - acc: 0.0994 - val_loss: 2.3033 - val_acc: 0.0969
#
# Epoch 00041: val_loss did not improve from 2.27110
# Epoch 42/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0998 - val_loss: 2.3031 - val_acc: 0.0996
#
# Epoch 00042: val_loss did not improve from 2.27110
# Epoch 43/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0980 - val_loss: 2.3035 - val_acc: 0.0987
#
# Epoch 00043: val_loss did not improve from 2.27110
# Epoch 44/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3035 - acc: 0.1004 - val_loss: 2.3030 - val_acc: 0.0956
#
# Epoch 00044: val_loss did not improve from 2.27110
# Epoch 45/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0990 - val_loss: 2.3029 - val_acc: 0.1009
#
# Epoch 00045: val_loss did not improve from 2.27110
# Epoch 46/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0984 - val_loss: 2.3037 - val_acc: 0.0987
#
# Epoch 00046: val_loss did not improve from 2.27110
# Epoch 47/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.1004 - val_loss: 2.3031 - val_acc: 0.0970
#
# Epoch 00047: val_loss did not improve from 2.27110
# Epoch 48/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3033 - acc: 0.0981 - val_loss: 2.3031 - val_acc: 0.0987
#
# Epoch 00048: val_loss did not improve from 2.27110
# Epoch 49/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3034 - acc: 0.0988 - val_loss: 2.3029 - val_acc: 0.1009
#
# Epoch 00049: val_loss did not improve from 2.27110
# Epoch 50/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 2.3032 - acc: 0.0997 - val_loss: 2.3034 - val_acc: 0.0996
#
# Epoch 00050: val_loss did not improve from 2.27110
# ==================
# batch size    : 32
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.05
# node size     : 128
# Epoch 1/50
# 1562/1562 [==============================] - 137s 87ms/step - loss: 1.2181 - acc: 0.5339 - val_loss: 1.0439 - val_acc: 0.6105
#
# Epoch 00001: val_loss improved from inf to 1.04385, saving model to models7/rnn_lstm.h5
# Epoch 2/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 0.8729 - acc: 0.6810 - val_loss: 0.8808 - val_acc: 0.6588
#
# Epoch 00002: val_loss improved from 1.04385 to 0.88075, saving model to models7/rnn_lstm.h5
# Epoch 3/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.4188 - acc: 0.4466 - val_loss: 1.8268 - val_acc: 0.2015
#
# Epoch 00003: val_loss did not improve from 0.88075
# Epoch 4/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.7996 - acc: 0.2227 - val_loss: 1.7407 - val_acc: 0.2582
#
# Epoch 00004: val_loss did not improve from 0.88075
# Epoch 5/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.7901 - acc: 0.2294 - val_loss: 1.8015 - val_acc: 0.2400
#
# Epoch 00005: val_loss did not improve from 0.88075
# Epoch 6/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8240 - acc: 0.2055 - val_loss: 1.8184 - val_acc: 0.2011
#
# Epoch 00006: val_loss did not improve from 0.88075
# Epoch 7/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8056 - acc: 0.2084 - val_loss: 1.8153 - val_acc: 0.2329
#
# Epoch 00007: val_loss did not improve from 0.88075
# Epoch 8/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8103 - acc: 0.2045 - val_loss: 1.8163 - val_acc: 0.2087
#
# Epoch 00008: val_loss did not improve from 0.88075
# Epoch 9/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8152 - acc: 0.1985 - val_loss: 1.8086 - val_acc: 0.1992
#
# Epoch 00009: val_loss did not improve from 0.88075
# Epoch 10/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8131 - acc: 0.2009 - val_loss: 1.8225 - val_acc: 0.2026
#
# Epoch 00010: val_loss did not improve from 0.88075
# Epoch 11/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8112 - acc: 0.2006 - val_loss: 1.8068 - val_acc: 0.2026
#
# Epoch 00011: val_loss did not improve from 0.88075
# Epoch 12/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8100 - acc: 0.1978 - val_loss: 1.8256 - val_acc: 0.1998
#
# Epoch 00012: val_loss did not improve from 0.88075
# Epoch 13/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8099 - acc: 0.2010 - val_loss: 1.8355 - val_acc: 0.2089
#
# Epoch 00013: val_loss did not improve from 0.88075
# Epoch 14/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.7934 - acc: 0.2114 - val_loss: 1.7188 - val_acc: 0.3115
#
# Epoch 00014: val_loss did not improve from 0.88075
# Epoch 15/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.7296 - acc: 0.2531 - val_loss: 1.8239 - val_acc: 0.1972
#
# Epoch 00015: val_loss did not improve from 0.88075
# Epoch 16/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8229 - acc: 0.2002 - val_loss: 1.8245 - val_acc: 0.2048
#
# Epoch 00016: val_loss did not improve from 0.88075
# Epoch 17/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8124 - acc: 0.1998 - val_loss: 1.8104 - val_acc: 0.1983
#
# Epoch 00017: val_loss did not improve from 0.88075
# Epoch 18/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8091 - acc: 0.2056 - val_loss: 1.8691 - val_acc: 0.2013
#
# Epoch 00018: val_loss did not improve from 0.88075
# Epoch 19/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8107 - acc: 0.2029 - val_loss: 1.8139 - val_acc: 0.2025
#
# Epoch 00019: val_loss did not improve from 0.88075
# Epoch 20/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8097 - acc: 0.1990 - val_loss: 1.8041 - val_acc: 0.2039
#
# Epoch 00020: val_loss did not improve from 0.88075
# Epoch 21/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8099 - acc: 0.2030 - val_loss: 1.8153 - val_acc: 0.2009
#
# Epoch 00021: val_loss did not improve from 0.88075
# Epoch 22/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8089 - acc: 0.2039 - val_loss: 1.8088 - val_acc: 0.2014
#
# Epoch 00022: val_loss did not improve from 0.88075
# Epoch 23/50
# 1562/1562 [==============================] - 136s 87ms/step - loss: 1.8087 - acc: 0.2006 - val_loss: 1.8071 - val_acc: 0.2018
#
# Epoch 00023: val_loss did not improve from 0.88075
# Epoch 24/50
# 1562/1562 [==============================] - 139s 89ms/step - loss: 1.8086 - acc: 0.2001 - val_loss: 1.8159 - val_acc: 0.2002
#
# Epoch 00024: val_loss did not improve from 0.88075
# Epoch 25/50
# 1562/1562 [==============================] - 137s 87ms/step - loss: 1.8081 - acc: 0.2050 - val_loss: 1.8199 - val_acc: 0.2055
#
# Epoch 00025: val_loss did not improve from 0.88075
# Epoch 26/50
# 1562/1562 [==============================] - 141s 90ms/step - loss: 1.8053 - acc: 0.2034 - val_loss: 1.8156 - val_acc: 0.2002
#
# Epoch 00026: val_loss did not improve from 0.88075
# Epoch 27/50
# 1562/1562 [==============================] - 148s 94ms/step - loss: 1.8070 - acc: 0.1998 - val_loss: 1.8280 - val_acc: 0.2050
#
# Epoch 00027: val_loss did not improve from 0.88075
# Epoch 28/50
# 1562/1562 [==============================] - 145s 93ms/step - loss: 1.8057 - acc: 0.2055 - val_loss: 1.8157 - val_acc: 0.2053
#
# Epoch 00028: val_loss did not improve from 0.88075
# Epoch 29/50
# 1562/1562 [==============================] - 146s 94ms/step - loss: 1.8053 - acc: 0.2040 - val_loss: 1.8440 - val_acc: 0.1858
#
# Epoch 00029: val_loss did not improve from 0.88075
# Epoch 30/50
#   55/1562 [>.............................] - ETA: 2:14 - loss: 1.8127 - acc: 0.2023

# %%
from google.colab import files

print(best_model)
print("Best Stats")
print("==========")
print("accuracy      : {}".format(best_accuracy))
print("batch size    : {}".format(best_batch_size))
print("epochs        : {}".format(best_epochs))
print("optimizer     : {}".format(best_optimizer))
print("learning rate : {}".format(best_learning_rate))
print("node size     : {}".format(best_node_size))

filepath = "models/rnn_lstm_best.h5"
files.download(filepath)
