# %%
# !mkdir models6

# %%
# !ls
# Out:
# models
# models2
# models3
# models4
# models5
# models6
# RNN_LSTM_Keras_working_35epo_selected.ipynb
# RNN_LSTM_Keras_working_50_epo_adam.ipynb
# RNN_LSTM_Keras_working_50_epo_selected.ipynb
# RNN_LSTM_Keras_working.ipynb
# RNN_LSTM_Keras_working-just_for_50ep_SGD_Momentum-Copy1.ipynb
# RNN_LSTM_Keras_working-just_for_50ep_SGD_No_Momentum.ipynb
# RNN_LSTM_Keras_working-just_for_SGD_Momentum.ipynb

# %%
# %matplotlib inline

from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras import optimizers

from keras.models import Model
from keras.layers import Input, Dense, TimeDistributed, LSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

import cv2
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


def img_resize(org_imgs, target_size):
  x_imgs = []
  for i in range(0,org_imgs.shape[0]):
    x_img = cv2.resize(org_imgs[i], dsize=(target_size, target_size), interpolation=cv2.INTER_CUBIC)
    x_imgs.append(x_img)
  return np.array(x_imgs)


def plot_model(model_details):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_details.history['loss'])+1),model_details.history['loss'])
    axs[1].plot(range(1,len(model_details.history['val_loss'])+1),model_details.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_details.history['loss'])+1),len(model_details.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_details.history['acc'])+1),model_details.history['acc'])
    axs[0].plot(range(1,len(model_details.history['val_acc'])+1),model_details.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_details.history['acc'])+1),len(model_details.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()
    
    
# Training parameters.
batch_sizes = [32,64]
num_epochs = [50]
learning_rates = [0.01,0.05]
optimizers_name = ['sgd']
num_classes = 10
node_sizes = [128]

# The data, shuffled and split between train and test sets.
(images, labels), (_, _) = fashion_mnist.load_data()

images_zoomed_in = img_resize(images, 48)
images_zoomed_in = images_zoomed_in.reshape(images_zoomed_in.shape[0], images_zoomed_in.shape[1], images_zoomed_in.shape[2], 1).astype('float32')

x_train = images_zoomed_in[0:50000]
x_test = images_zoomed_in[50000:60000]

y_train = labels[0:50000]
y_test = labels[50000:60000]


# x_train -= np.mean(x_train)
# x_test -= np.mean(x_train)

# x_train /= np.std(x_train)
# x_test /= np.std(x_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


TRAIN_DATA_SIZE = x_train.shape[0]
TEST_DATA_SIZE = x_test.shape[0]

#TRAIN_BATCH_SIZE = 20
#TEST_BATCH_SIZE = 10

#train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
#test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)


# Converts class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

train_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
train_gen.fit(x_train)
#train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

test_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
test_gen.fit(x_train)
#test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

#row, col, pixel = x_train.shape[1:]


best_model = None
best_accuracy = 0
best_batch_size = 0
best_epochs = 0
best_optimizer = ''
best_learning_rate = 0
best_node_size = 0
# Out:
# /home/ryantsan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (50000, 48, 48, 1)
# 50000 train samples
# 10000 test samples

# %%
for batch_size in batch_sizes:
  for epochs in num_epochs:
    for optimizer_name in optimizers_name:
      for learning_rate in learning_rates:
        for node_size in node_sizes:
            print("==================")
            print("batch size    : {}".format(batch_size))
            print("epochs        : {}".format(epochs))
            print("optimizer     : {}".format(optimizer_name))
            print("learning rate : {}".format(learning_rate))
            print("node size     : {}".format(node_size))

            if optimizer_name == 'adam':
              optimizer = optimizers.Adam(lr=learning_rate)
            elif optimizer_name == 'rmsprop':
              optimizer = optimizers.RMSprop(lr=learning_rate)
            elif optimizer_name == 'sgd':
              optimizer = optimizers.SGD(lr=learning_rate)

            # Embedding dimensions.
            row_hidden = node_size
            col_hidden = node_size

            
            TRAIN_BATCH_SIZE = batch_size
            TEST_BATCH_SIZE = (batch_size)
            TEST_BATCH_SIZE
            
            train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
            test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)
            
            train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

            test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

            row, col, pixel = x_train.shape[1:]
            
            
            # 4D input.
            x = Input(shape=(row, col, pixel))

            # Encodes a row of pixels using TimeDistributed Wrapper.
            encoded_rows = TimeDistributed(LSTM(row_hidden))(x)

            # Encodes columns of encoded rows.
            encoded_columns = LSTM(col_hidden)(encoded_rows)

            # Final predictions and model.
            prediction = Dense(num_classes, activation='softmax')(encoded_columns)

            model = Model(x, prediction)
            model.compile(loss='categorical_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])

            


            # Training.
            # model.fit(x_train, y_train,
            #           batch_size=batch_size,
            #           epochs=epochs,
            #           verbose=1,
            #           validation_data=(x_test, y_test))
            model_file_name = "models6/rnn_lstm_{}_{}_{}_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size)
            checkpoint = ModelCheckpoint(model_file_name, monitor='val_loss', verbose=0, save_best_only= True, mode='auto')

            best_model_file_name = "models6/rnn_lstm.h5"
            best_checkpoint = ModelCheckpoint(best_model_file_name, monitor='val_loss', verbose=1, save_best_only= True, mode='auto')
       
            h = model.fit_generator(train_batches, steps_per_epoch=train_step, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], validation_steps=test_step, epochs=epochs, verbose=1)
            #h = model.fit_generator(train_batches, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], verbose=1)
  
            plot_model(h)
# Out:
# ==================
# batch size    : 32
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.01
# node size     : 128
# Epoch 1/50
# 1562/1562 [==============================] - 139s 89ms/step - loss: 1.8916 - acc: 0.3039 - val_loss: 1.4164 - val_acc: 0.4402
#
# Epoch 00001: val_loss improved from inf to 1.41637, saving model to models6/rnn_lstm.h5
# Epoch 2/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 1.2686 - acc: 0.4971 - val_loss: 1.1251 - val_acc: 0.5591
#
# Epoch 00002: val_loss improved from 1.41637 to 1.12511, saving model to models6/rnn_lstm.h5
# Epoch 3/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.9590 - acc: 0.6336 - val_loss: 0.8338 - val_acc: 0.6857
#
# Epoch 00003: val_loss improved from 1.12511 to 0.83384, saving model to models6/rnn_lstm.h5
# Epoch 4/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.7280 - acc: 0.7332 - val_loss: 0.6544 - val_acc: 0.7623
#
# Epoch 00004: val_loss improved from 0.83384 to 0.65439, saving model to models6/rnn_lstm.h5
# Epoch 5/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.6100 - acc: 0.7767 - val_loss: 0.5660 - val_acc: 0.7983
#
# Epoch 00005: val_loss improved from 0.65439 to 0.56601, saving model to models6/rnn_lstm.h5
# Epoch 6/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.5373 - acc: 0.8039 - val_loss: 0.5201 - val_acc: 0.8143
#
# Epoch 00006: val_loss improved from 0.56601 to 0.52012, saving model to models6/rnn_lstm.h5
# Epoch 7/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4941 - acc: 0.8210 - val_loss: 0.4956 - val_acc: 0.8218
#
# Epoch 00007: val_loss improved from 0.52012 to 0.49557, saving model to models6/rnn_lstm.h5
# Epoch 8/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4625 - acc: 0.8311 - val_loss: 0.4381 - val_acc: 0.8400
#
# Epoch 00008: val_loss improved from 0.49557 to 0.43809, saving model to models6/rnn_lstm.h5
# Epoch 9/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4461 - acc: 0.8350 - val_loss: 0.4373 - val_acc: 0.8384
#
# Epoch 00009: val_loss improved from 0.43809 to 0.43729, saving model to models6/rnn_lstm.h5
# Epoch 10/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4224 - acc: 0.8448 - val_loss: 0.4217 - val_acc: 0.8453
#
# Epoch 00010: val_loss improved from 0.43729 to 0.42174, saving model to models6/rnn_lstm.h5
# Epoch 11/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4083 - acc: 0.8497 - val_loss: 0.3942 - val_acc: 0.8535
#
# Epoch 00011: val_loss improved from 0.42174 to 0.39418, saving model to models6/rnn_lstm.h5
# Epoch 12/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3917 - acc: 0.8557 - val_loss: 0.3955 - val_acc: 0.8556
#
# Epoch 00012: val_loss did not improve from 0.39418
# Epoch 13/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3970 - acc: 0.8546 - val_loss: 0.3918 - val_acc: 0.8551
#
# Epoch 00013: val_loss improved from 0.39418 to 0.39180, saving model to models6/rnn_lstm.h5
# Epoch 14/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3762 - acc: 0.8630 - val_loss: 0.3866 - val_acc: 0.8586
#
# Epoch 00014: val_loss improved from 0.39180 to 0.38656, saving model to models6/rnn_lstm.h5
# Epoch 15/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3660 - acc: 0.8651 - val_loss: 0.3810 - val_acc: 0.8589
#
# Epoch 00015: val_loss improved from 0.38656 to 0.38103, saving model to models6/rnn_lstm.h5
# Epoch 16/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3528 - acc: 0.8697 - val_loss: 0.3673 - val_acc: 0.8649
#
# Epoch 00016: val_loss improved from 0.38103 to 0.36730, saving model to models6/rnn_lstm.h5
# Epoch 17/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3472 - acc: 0.8724 - val_loss: 0.3521 - val_acc: 0.8680
#
# Epoch 00017: val_loss improved from 0.36730 to 0.35214, saving model to models6/rnn_lstm.h5
# Epoch 18/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3409 - acc: 0.8740 - val_loss: 0.3521 - val_acc: 0.8732
#
# Epoch 00018: val_loss did not improve from 0.35214
# Epoch 19/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3358 - acc: 0.8761 - val_loss: 0.3414 - val_acc: 0.8755
#
# Epoch 00019: val_loss improved from 0.35214 to 0.34137, saving model to models6/rnn_lstm.h5
# Epoch 20/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3289 - acc: 0.8785 - val_loss: 0.3401 - val_acc: 0.8754
#
# Epoch 00020: val_loss improved from 0.34137 to 0.34010, saving model to models6/rnn_lstm.h5
# Epoch 21/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3251 - acc: 0.8821 - val_loss: 0.3412 - val_acc: 0.8789
#
# Epoch 00021: val_loss did not improve from 0.34010
# Epoch 22/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3173 - acc: 0.8835 - val_loss: 0.3376 - val_acc: 0.8782
#
# Epoch 00022: val_loss improved from 0.34010 to 0.33759, saving model to models6/rnn_lstm.h5
# Epoch 23/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3168 - acc: 0.8836 - val_loss: 0.3387 - val_acc: 0.8762
#
# Epoch 00023: val_loss did not improve from 0.33759
# Epoch 24/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3136 - acc: 0.8839 - val_loss: 0.3421 - val_acc: 0.8766
#
# Epoch 00024: val_loss did not improve from 0.33759
# Epoch 25/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3044 - acc: 0.8885 - val_loss: 0.3364 - val_acc: 0.8770
#
# Epoch 00025: val_loss improved from 0.33759 to 0.33636, saving model to models6/rnn_lstm.h5
# Epoch 26/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2997 - acc: 0.8897 - val_loss: 0.3213 - val_acc: 0.8828
#
# Epoch 00026: val_loss improved from 0.33636 to 0.32130, saving model to models6/rnn_lstm.h5
# Epoch 27/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2974 - acc: 0.8904 - val_loss: 0.3247 - val_acc: 0.8797
#
# Epoch 00027: val_loss did not improve from 0.32130
# Epoch 28/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2932 - acc: 0.8918 - val_loss: 0.3198 - val_acc: 0.8832
#
# Epoch 00028: val_loss improved from 0.32130 to 0.31979, saving model to models6/rnn_lstm.h5
# Epoch 29/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2871 - acc: 0.8940 - val_loss: 0.3283 - val_acc: 0.8800
#
# Epoch 00029: val_loss did not improve from 0.31979
# Epoch 30/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2918 - acc: 0.8928 - val_loss: 0.3234 - val_acc: 0.8825
#
# Epoch 00030: val_loss did not improve from 0.31979
# Epoch 31/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2801 - acc: 0.8970 - val_loss: 0.3133 - val_acc: 0.8876
#
# Epoch 00031: val_loss improved from 0.31979 to 0.31329, saving model to models6/rnn_lstm.h5
# Epoch 32/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2780 - acc: 0.8963 - val_loss: 0.3123 - val_acc: 0.8871
#
# Epoch 00032: val_loss improved from 0.31329 to 0.31227, saving model to models6/rnn_lstm.h5
# Epoch 33/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2730 - acc: 0.8975 - val_loss: 0.3167 - val_acc: 0.8843
#
# Epoch 00033: val_loss did not improve from 0.31227
# Epoch 34/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2731 - acc: 0.8989 - val_loss: 0.3233 - val_acc: 0.8802
#
# Epoch 00034: val_loss did not improve from 0.31227
# Epoch 35/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2708 - acc: 0.9000 - val_loss: 0.3153 - val_acc: 0.8842
#
# Epoch 00035: val_loss did not improve from 0.31227
# Epoch 36/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2647 - acc: 0.9013 - val_loss: 0.3038 - val_acc: 0.8902
#
# Epoch 00036: val_loss improved from 0.31227 to 0.30378, saving model to models6/rnn_lstm.h5
# Epoch 37/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2628 - acc: 0.9030 - val_loss: 0.3210 - val_acc: 0.8845
#
# Epoch 00037: val_loss did not improve from 0.30378
# Epoch 38/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2609 - acc: 0.9025 - val_loss: 0.3100 - val_acc: 0.8877
#
# Epoch 00038: val_loss did not improve from 0.30378
# Epoch 39/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2585 - acc: 0.9047 - val_loss: 0.3060 - val_acc: 0.8901
#
# Epoch 00039: val_loss did not improve from 0.30378
# Epoch 40/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2569 - acc: 0.9055 - val_loss: 0.3017 - val_acc: 0.8899
#
# Epoch 00040: val_loss improved from 0.30378 to 0.30174, saving model to models6/rnn_lstm.h5
# Epoch 41/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2517 - acc: 0.9057 - val_loss: 0.3175 - val_acc: 0.8859
#
# Epoch 00041: val_loss did not improve from 0.30174
# Epoch 42/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2488 - acc: 0.9073 - val_loss: 0.2988 - val_acc: 0.8947
#
# Epoch 00042: val_loss improved from 0.30174 to 0.29881, saving model to models6/rnn_lstm.h5
# Epoch 43/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2474 - acc: 0.9079 - val_loss: 0.3042 - val_acc: 0.8881
#
# Epoch 00043: val_loss did not improve from 0.29881
# Epoch 44/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2464 - acc: 0.9070 - val_loss: 0.3109 - val_acc: 0.8859
#
# Epoch 00044: val_loss did not improve from 0.29881
# Epoch 45/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2436 - acc: 0.9094 - val_loss: 0.3018 - val_acc: 0.8910
#
# Epoch 00045: val_loss did not improve from 0.29881
# Epoch 46/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2558 - acc: 0.9060 - val_loss: 0.4138 - val_acc: 0.8505
#
# Epoch 00046: val_loss did not improve from 0.29881
# Epoch 47/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2783 - acc: 0.8976 - val_loss: 0.3075 - val_acc: 0.8889
#
# Epoch 00047: val_loss did not improve from 0.29881
# Epoch 48/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2407 - acc: 0.9109 - val_loss: 0.2955 - val_acc: 0.8928
#
# Epoch 00048: val_loss improved from 0.29881 to 0.29552, saving model to models6/rnn_lstm.h5
# Epoch 49/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2348 - acc: 0.9121 - val_loss: 0.3019 - val_acc: 0.8898
#
# Epoch 00049: val_loss did not improve from 0.29552
# Epoch 50/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2354 - acc: 0.9126 - val_loss: 0.2942 - val_acc: 0.8951
#
# Epoch 00050: val_loss improved from 0.29552 to 0.29422, saving model to models6/rnn_lstm.h5
# ==================
# batch size    : 32
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.05
# node size     : 128
# Epoch 1/50
# 1562/1562 [==============================] - 138s 89ms/step - loss: 1.2140 - acc: 0.5380 - val_loss: 0.7629 - val_acc: 0.7121
#
# Epoch 00001: val_loss improved from inf to 0.76294, saving model to models6/rnn_lstm.h5
# Epoch 2/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.6391 - acc: 0.7681 - val_loss: 0.5612 - val_acc: 0.7934
#
# Epoch 00002: val_loss improved from 0.76294 to 0.56125, saving model to models6/rnn_lstm.h5
# Epoch 3/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.5041 - acc: 0.8173 - val_loss: 0.4831 - val_acc: 0.8255
#
# Epoch 00003: val_loss improved from 0.56125 to 0.48312, saving model to models6/rnn_lstm.h5
# Epoch 4/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4494 - acc: 0.8378 - val_loss: 0.4130 - val_acc: 0.8537
#
# Epoch 00004: val_loss improved from 0.48312 to 0.41301, saving model to models6/rnn_lstm.h5
# Epoch 5/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.4205 - acc: 0.8467 - val_loss: 0.4047 - val_acc: 0.8510
#
# Epoch 00005: val_loss improved from 0.41301 to 0.40473, saving model to models6/rnn_lstm.h5
# Epoch 6/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3984 - acc: 0.8532 - val_loss: 0.3915 - val_acc: 0.8579
#
# Epoch 00006: val_loss improved from 0.40473 to 0.39153, saving model to models6/rnn_lstm.h5
# Epoch 7/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3837 - acc: 0.8607 - val_loss: 0.3656 - val_acc: 0.8654
#
# Epoch 00007: val_loss improved from 0.39153 to 0.36563, saving model to models6/rnn_lstm.h5
# Epoch 8/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3723 - acc: 0.8643 - val_loss: 1.1597 - val_acc: 0.5521
#
# Epoch 00008: val_loss did not improve from 0.36563
# Epoch 9/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.4812 - acc: 0.8243 - val_loss: 0.3802 - val_acc: 0.8570
#
# Epoch 00009: val_loss did not improve from 0.36563
# Epoch 10/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.3598 - acc: 0.8682 - val_loss: 0.3623 - val_acc: 0.8675
#
# Epoch 00010: val_loss improved from 0.36563 to 0.36229, saving model to models6/rnn_lstm.h5
# Epoch 11/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3294 - acc: 0.8788 - val_loss: 0.3480 - val_acc: 0.8701
#
# Epoch 00011: val_loss improved from 0.36229 to 0.34800, saving model to models6/rnn_lstm.h5
# Epoch 12/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3143 - acc: 0.8842 - val_loss: 0.3353 - val_acc: 0.8754
#
# Epoch 00012: val_loss improved from 0.34800 to 0.33531, saving model to models6/rnn_lstm.h5
# Epoch 13/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.3025 - acc: 0.8869 - val_loss: 0.3298 - val_acc: 0.8772
#
# Epoch 00013: val_loss improved from 0.33531 to 0.32984, saving model to models6/rnn_lstm.h5
# Epoch 14/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2923 - acc: 0.8922 - val_loss: 0.3171 - val_acc: 0.8825
#
# Epoch 00014: val_loss improved from 0.32984 to 0.31708, saving model to models6/rnn_lstm.h5
# Epoch 15/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2833 - acc: 0.8949 - val_loss: 0.3059 - val_acc: 0.8882
#
# Epoch 00015: val_loss improved from 0.31708 to 0.30587, saving model to models6/rnn_lstm.h5
# Epoch 16/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2753 - acc: 0.8972 - val_loss: 0.3050 - val_acc: 0.8862
#
# Epoch 00016: val_loss improved from 0.30587 to 0.30497, saving model to models6/rnn_lstm.h5
# Epoch 17/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2692 - acc: 0.8998 - val_loss: 0.3000 - val_acc: 0.8897
#
# Epoch 00017: val_loss improved from 0.30497 to 0.30004, saving model to models6/rnn_lstm.h5
# Epoch 18/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2646 - acc: 0.9016 - val_loss: 0.3175 - val_acc: 0.8824
#
# Epoch 00018: val_loss did not improve from 0.30004
# Epoch 19/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2580 - acc: 0.9044 - val_loss: 0.3018 - val_acc: 0.8888
#
# Epoch 00019: val_loss did not improve from 0.30004
# Epoch 20/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2522 - acc: 0.9066 - val_loss: 0.2872 - val_acc: 0.8956
#
# Epoch 00020: val_loss improved from 0.30004 to 0.28724, saving model to models6/rnn_lstm.h5
# Epoch 21/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2461 - acc: 0.9086 - val_loss: 0.2858 - val_acc: 0.8939
#
# Epoch 00021: val_loss improved from 0.28724 to 0.28582, saving model to models6/rnn_lstm.h5
# Epoch 22/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2404 - acc: 0.9110 - val_loss: 0.2888 - val_acc: 0.8963
#
# Epoch 00022: val_loss did not improve from 0.28582
# Epoch 23/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2341 - acc: 0.9129 - val_loss: 0.2802 - val_acc: 0.8975
#
# Epoch 00023: val_loss improved from 0.28582 to 0.28019, saving model to models6/rnn_lstm.h5
# Epoch 24/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2289 - acc: 0.9144 - val_loss: 0.2878 - val_acc: 0.8946
#
# Epoch 00024: val_loss did not improve from 0.28019
# Epoch 25/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2232 - acc: 0.9157 - val_loss: 0.2769 - val_acc: 0.8989
#
# Epoch 00025: val_loss improved from 0.28019 to 0.27685, saving model to models6/rnn_lstm.h5
# Epoch 26/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2154 - acc: 0.9198 - val_loss: 0.2732 - val_acc: 0.8990
#
# Epoch 00026: val_loss improved from 0.27685 to 0.27320, saving model to models6/rnn_lstm.h5
# Epoch 27/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2096 - acc: 0.9220 - val_loss: 0.2788 - val_acc: 0.8996
#
# Epoch 00027: val_loss did not improve from 0.27320
# Epoch 28/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2125 - acc: 0.9208 - val_loss: 0.2755 - val_acc: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.27320
# Epoch 29/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.2033 - acc: 0.9242 - val_loss: 0.2611 - val_acc: 0.9050
#
# Epoch 00029: val_loss improved from 0.27320 to 0.26111, saving model to models6/rnn_lstm.h5
# Epoch 30/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.2008 - acc: 0.9256 - val_loss: 0.2700 - val_acc: 0.9035
#
# Epoch 00030: val_loss did not improve from 0.26111
# Epoch 31/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.1942 - acc: 0.9277 - val_loss: 0.2729 - val_acc: 0.9036
#
# Epoch 00031: val_loss did not improve from 0.26111
# Epoch 32/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1919 - acc: 0.9275 - val_loss: 0.2686 - val_acc: 0.9050
#
# Epoch 00032: val_loss did not improve from 0.26111
# Epoch 33/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1850 - acc: 0.9303 - val_loss: 0.2529 - val_acc: 0.9093
#
# Epoch 00033: val_loss improved from 0.26111 to 0.25293, saving model to models6/rnn_lstm.h5
# Epoch 34/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.1812 - acc: 0.9327 - val_loss: 0.2680 - val_acc: 0.9052
#
# Epoch 00034: val_loss did not improve from 0.25293
# Epoch 35/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1782 - acc: 0.9347 - val_loss: 0.2558 - val_acc: 0.9083
#
# Epoch 00035: val_loss did not improve from 0.25293
# Epoch 36/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.1734 - acc: 0.9350 - val_loss: 0.2630 - val_acc: 0.9047
#
# Epoch 00036: val_loss did not improve from 0.25293
# Epoch 37/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1675 - acc: 0.9375 - val_loss: 0.2756 - val_acc: 0.9011
#
# Epoch 00037: val_loss did not improve from 0.25293
# Epoch 38/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.1670 - acc: 0.9383 - val_loss: 0.2774 - val_acc: 0.9035
#
# Epoch 00038: val_loss did not improve from 0.25293
# Epoch 39/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1637 - acc: 0.9385 - val_loss: 0.2619 - val_acc: 0.9100
#
# Epoch 00039: val_loss did not improve from 0.25293
# Epoch 40/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1713 - acc: 0.9364 - val_loss: 0.2577 - val_acc: 0.9098
#
# Epoch 00040: val_loss did not improve from 0.25293
# Epoch 41/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1888 - acc: 0.9301 - val_loss: 0.2537 - val_acc: 0.9126
#
# Epoch 00041: val_loss did not improve from 0.25293
# Epoch 42/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1536 - acc: 0.9427 - val_loss: 0.2635 - val_acc: 0.9116
#
# Epoch 00042: val_loss did not improve from 0.25293
# Epoch 43/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1513 - acc: 0.9442 - val_loss: 0.2584 - val_acc: 0.9126
#
# Epoch 00043: val_loss did not improve from 0.25293
# Epoch 44/50
# 1562/1562 [==============================] - 137s 88ms/step - loss: 0.1485 - acc: 0.9454 - val_loss: 0.2638 - val_acc: 0.9076
#
# Epoch 00044: val_loss did not improve from 0.25293
# Epoch 45/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1452 - acc: 0.9469 - val_loss: 0.2634 - val_acc: 0.9102
#
# Epoch 00045: val_loss did not improve from 0.25293
# Epoch 46/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1407 - acc: 0.9474 - val_loss: 0.2583 - val_acc: 0.9135
#
# Epoch 00046: val_loss did not improve from 0.25293
# Epoch 47/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1350 - acc: 0.9498 - val_loss: 0.2722 - val_acc: 0.9083
#
# Epoch 00047: val_loss did not improve from 0.25293
# Epoch 48/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1317 - acc: 0.9512 - val_loss: 0.2786 - val_acc: 0.9065
#
# Epoch 00048: val_loss did not improve from 0.25293
# Epoch 49/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1337 - acc: 0.9504 - val_loss: 0.2770 - val_acc: 0.9070
#
# Epoch 00049: val_loss did not improve from 0.25293
# Epoch 50/50
# 1562/1562 [==============================] - 138s 88ms/step - loss: 0.1291 - acc: 0.9522 - val_loss: 0.2705 - val_acc: 0.9099
#
# Epoch 00050: val_loss did not improve from 0.25293
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.01
# node size     : 128
# Epoch 1/50
# 781/781 [==============================] - 92s 117ms/step - loss: 2.2397 - acc: 0.1695 - val_loss: 1.9977 - val_acc: 0.2653
#
# Epoch 00001: val_loss improved from inf to 1.99768, saving model to models6/rnn_lstm.h5
# Epoch 2/50
# 781/781 [==============================] - 91s 116ms/step - loss: 1.6148 - acc: 0.3866 - val_loss: 1.3735 - val_acc: 0.4439
#
# Epoch 00002: val_loss improved from 1.99768 to 1.37351, saving model to models6/rnn_lstm.h5
# Epoch 3/50
# 781/781 [==============================] - 91s 116ms/step - loss: 1.2753 - acc: 0.4864 - val_loss: 1.1668 - val_acc: 0.5317
#
# Epoch 00003: val_loss improved from 1.37351 to 1.16683, saving model to models6/rnn_lstm.h5
# Epoch 4/50
# 781/781 [==============================] - 91s 116ms/step - loss: 1.0589 - acc: 0.5911 - val_loss: 0.9239 - val_acc: 0.6741
#
# Epoch 00004: val_loss improved from 1.16683 to 0.92394, saving model to models6/rnn_lstm.h5
# Epoch 5/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.8475 - acc: 0.6935 - val_loss: 0.7596 - val_acc: 0.7342
#
# Epoch 00005: val_loss improved from 0.92394 to 0.75961, saving model to models6/rnn_lstm.h5
# Epoch 6/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.7244 - acc: 0.7422 - val_loss: 0.6732 - val_acc: 0.7632
#
# Epoch 00006: val_loss improved from 0.75961 to 0.67316, saving model to models6/rnn_lstm.h5
# Epoch 7/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.6570 - acc: 0.7641 - val_loss: 0.6351 - val_acc: 0.7718
#
# Epoch 00007: val_loss improved from 0.67316 to 0.63514, saving model to models6/rnn_lstm.h5
# Epoch 8/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.6062 - acc: 0.7820 - val_loss: 0.6116 - val_acc: 0.7776
#
# Epoch 00008: val_loss improved from 0.63514 to 0.61158, saving model to models6/rnn_lstm.h5
# Epoch 9/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.5638 - acc: 0.7979 - val_loss: 0.5323 - val_acc: 0.8051
#
# Epoch 00009: val_loss improved from 0.61158 to 0.53230, saving model to models6/rnn_lstm.h5
# Epoch 10/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.5325 - acc: 0.8070 - val_loss: 0.5317 - val_acc: 0.8062
#
# Epoch 00010: val_loss improved from 0.53230 to 0.53171, saving model to models6/rnn_lstm.h5
# Epoch 11/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.5037 - acc: 0.8183 - val_loss: 0.5147 - val_acc: 0.8118
#
# Epoch 00011: val_loss improved from 0.53171 to 0.51473, saving model to models6/rnn_lstm.h5
# Epoch 12/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4989 - acc: 0.8194 - val_loss: 0.4963 - val_acc: 0.8176
#
# Epoch 00012: val_loss improved from 0.51473 to 0.49635, saving model to models6/rnn_lstm.h5
# Epoch 13/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4701 - acc: 0.8291 - val_loss: 0.4669 - val_acc: 0.8286
#
# Epoch 00013: val_loss improved from 0.49635 to 0.46687, saving model to models6/rnn_lstm.h5
# Epoch 14/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4547 - acc: 0.8339 - val_loss: 0.4497 - val_acc: 0.8357
#
# Epoch 00014: val_loss improved from 0.46687 to 0.44967, saving model to models6/rnn_lstm.h5
# Epoch 15/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4382 - acc: 0.8383 - val_loss: 0.4420 - val_acc: 0.8368
#
# Epoch 00015: val_loss improved from 0.44967 to 0.44196, saving model to models6/rnn_lstm.h5
# Epoch 16/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4264 - acc: 0.8437 - val_loss: 0.4335 - val_acc: 0.8422
#
# Epoch 00016: val_loss improved from 0.44196 to 0.43348, saving model to models6/rnn_lstm.h5
# Epoch 17/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4177 - acc: 0.8466 - val_loss: 0.4280 - val_acc: 0.8436
#
# Epoch 00017: val_loss improved from 0.43348 to 0.42799, saving model to models6/rnn_lstm.h5
# Epoch 18/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4068 - acc: 0.8518 - val_loss: 0.4274 - val_acc: 0.8442
#
# Epoch 00018: val_loss improved from 0.42799 to 0.42736, saving model to models6/rnn_lstm.h5
# Epoch 19/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4015 - acc: 0.8524 - val_loss: 0.4241 - val_acc: 0.8472
#
# Epoch 00019: val_loss improved from 0.42736 to 0.42410, saving model to models6/rnn_lstm.h5
# Epoch 20/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4071 - acc: 0.8514 - val_loss: 0.4118 - val_acc: 0.8500
#
# Epoch 00020: val_loss improved from 0.42410 to 0.41179, saving model to models6/rnn_lstm.h5
# Epoch 21/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3898 - acc: 0.8575 - val_loss: 0.3847 - val_acc: 0.8604
#
# Epoch 00021: val_loss improved from 0.41179 to 0.38465, saving model to models6/rnn_lstm.h5
# Epoch 22/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3801 - acc: 0.8601 - val_loss: 0.3884 - val_acc: 0.8584
#
# Epoch 00022: val_loss did not improve from 0.38465
# Epoch 23/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3733 - acc: 0.8638 - val_loss: 0.3793 - val_acc: 0.8641
#
# Epoch 00023: val_loss improved from 0.38465 to 0.37933, saving model to models6/rnn_lstm.h5
# Epoch 24/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3704 - acc: 0.8651 - val_loss: 0.3782 - val_acc: 0.8629
#
# Epoch 00024: val_loss improved from 0.37933 to 0.37818, saving model to models6/rnn_lstm.h5
# Epoch 25/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3641 - acc: 0.8661 - val_loss: 0.3691 - val_acc: 0.8655
#
# Epoch 00025: val_loss improved from 0.37818 to 0.36911, saving model to models6/rnn_lstm.h5
# Epoch 26/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3584 - acc: 0.8693 - val_loss: 0.3762 - val_acc: 0.8643
#
# Epoch 00026: val_loss did not improve from 0.36911
# Epoch 27/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3524 - acc: 0.8694 - val_loss: 0.3603 - val_acc: 0.8694
#
# Epoch 00027: val_loss improved from 0.36911 to 0.36034, saving model to models6/rnn_lstm.h5
# Epoch 28/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3602 - acc: 0.8687 - val_loss: 0.3625 - val_acc: 0.8687
#
# Epoch 00028: val_loss did not improve from 0.36034
# Epoch 29/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3423 - acc: 0.8743 - val_loss: 0.3859 - val_acc: 0.8605
#
# Epoch 00029: val_loss did not improve from 0.36034
# Epoch 30/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3609 - acc: 0.8694 - val_loss: 0.3748 - val_acc: 0.8644
#
# Epoch 00030: val_loss did not improve from 0.36034
# Epoch 31/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3375 - acc: 0.8770 - val_loss: 0.3559 - val_acc: 0.8699
#
# Epoch 00031: val_loss improved from 0.36034 to 0.35588, saving model to models6/rnn_lstm.h5
# Epoch 32/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3347 - acc: 0.8776 - val_loss: 0.3503 - val_acc: 0.8736
#
# Epoch 00032: val_loss improved from 0.35588 to 0.35034, saving model to models6/rnn_lstm.h5
# Epoch 33/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3284 - acc: 0.8800 - val_loss: 0.3503 - val_acc: 0.8738
#
# Epoch 00033: val_loss improved from 0.35034 to 0.35031, saving model to models6/rnn_lstm.h5
# Epoch 34/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3264 - acc: 0.8810 - val_loss: 0.3468 - val_acc: 0.8756
#
# Epoch 00034: val_loss improved from 0.35031 to 0.34678, saving model to models6/rnn_lstm.h5
# Epoch 35/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3224 - acc: 0.8810 - val_loss: 0.3501 - val_acc: 0.8716
#
# Epoch 00035: val_loss did not improve from 0.34678
# Epoch 36/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3211 - acc: 0.8821 - val_loss: 0.3566 - val_acc: 0.8684
#
# Epoch 00036: val_loss did not improve from 0.34678
# Epoch 37/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3154 - acc: 0.8840 - val_loss: 0.3552 - val_acc: 0.8664
# Epoch 00037: val_loss did not improve from 0.34678
# Epoch 38/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3176 - acc: 0.8832 - val_loss: 0.3412 - val_acc: 0.8736
#
# Epoch 00038: val_loss improved from 0.34678 to 0.34120, saving model to models6/rnn_lstm.h5
# Epoch 39/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3107 - acc: 0.8842 - val_loss: 0.3527 - val_acc: 0.8700
#
# Epoch 00039: val_loss did not improve from 0.34120
# Epoch 40/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3136 - acc: 0.8852 - val_loss: 0.3351 - val_acc: 0.8783
#
# Epoch 00040: val_loss improved from 0.34120 to 0.33514, saving model to models6/rnn_lstm.h5
# Epoch 41/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3076 - acc: 0.8864 - val_loss: 0.3331 - val_acc: 0.8776
#
# Epoch 00041: val_loss improved from 0.33514 to 0.33313, saving model to models6/rnn_lstm.h5
# Epoch 42/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3032 - acc: 0.8898 - val_loss: 0.3368 - val_acc: 0.8758
#
# Epoch 00042: val_loss did not improve from 0.33313
# Epoch 43/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3007 - acc: 0.8896 - val_loss: 0.3381 - val_acc: 0.8749
#
# Epoch 00043: val_loss did not improve from 0.33313
# Epoch 44/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3124 - acc: 0.8854 - val_loss: 0.3260 - val_acc: 0.8811
#
# Epoch 00044: val_loss improved from 0.33313 to 0.32601, saving model to models6/rnn_lstm.h5
# Epoch 45/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2971 - acc: 0.8913 - val_loss: 0.3285 - val_acc: 0.8804
#
# Epoch 00045: val_loss did not improve from 0.32601
# Epoch 46/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2937 - acc: 0.8919 - val_loss: 0.3283 - val_acc: 0.8795
#
# Epoch 00046: val_loss did not improve from 0.32601
# Epoch 47/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2933 - acc: 0.8905 - val_loss: 0.3254 - val_acc: 0.8821
#
# Epoch 00047: val_loss improved from 0.32601 to 0.32541, saving model to models6/rnn_lstm.h5
# Epoch 48/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2879 - acc: 0.8944 - val_loss: 0.3120 - val_acc: 0.8886
#
# Epoch 00048: val_loss improved from 0.32541 to 0.31204, saving model to models6/rnn_lstm.h5
# Epoch 49/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2880 - acc: 0.8940 - val_loss: 0.3229 - val_acc: 0.8821
#
# Epoch 00049: val_loss did not improve from 0.31204
# Epoch 50/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2820 - acc: 0.8965 - val_loss: 0.3417 - val_acc: 0.8758
#
# Epoch 00050: val_loss did not improve from 0.31204
# ==================
# batch size    : 64
# epochs        : 50
# optimizer     : sgd
# learning rate : 0.05
# node size     : 128
# Epoch 1/50
# 781/781 [==============================] - 92s 117ms/step - loss: 1.5069 - acc: 0.4188 - val_loss: 1.0341 - val_acc: 0.6069
#
# Epoch 00001: val_loss improved from inf to 1.03410, saving model to models6/rnn_lstm.h5
# Epoch 2/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.8356 - acc: 0.6912 - val_loss: 0.6466 - val_acc: 0.7730
#
# Epoch 00002: val_loss improved from 1.03410 to 0.64655, saving model to models6/rnn_lstm.h5
# Epoch 3/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.6614 - acc: 0.7653 - val_loss: 0.5496 - val_acc: 0.8007
#
# Epoch 00003: val_loss improved from 0.64655 to 0.54962, saving model to models6/rnn_lstm.h5
# Epoch 4/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.5242 - acc: 0.8102 - val_loss: 0.4607 - val_acc: 0.8315
#
# Epoch 00004: val_loss improved from 0.54962 to 0.46075, saving model to models6/rnn_lstm.h5
# Epoch 5/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4742 - acc: 0.8277 - val_loss: 0.4684 - val_acc: 0.8292
#
# Epoch 00005: val_loss did not improve from 0.46075
# Epoch 6/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4261 - acc: 0.8435 - val_loss: 0.4416 - val_acc: 0.8376
#
# Epoch 00006: val_loss improved from 0.46075 to 0.44163, saving model to models6/rnn_lstm.h5
# Epoch 7/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.4080 - acc: 0.8510 - val_loss: 0.4461 - val_acc: 0.8342
#
# Epoch 00007: val_loss did not improve from 0.44163
# Epoch 8/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3895 - acc: 0.8562 - val_loss: 0.3930 - val_acc: 0.8540
#
# Epoch 00008: val_loss improved from 0.44163 to 0.39299, saving model to models6/rnn_lstm.h5
# Epoch 9/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3734 - acc: 0.8627 - val_loss: 0.3798 - val_acc: 0.8626
#
# Epoch 00009: val_loss improved from 0.39299 to 0.37983, saving model to models6/rnn_lstm.h5
# Epoch 10/50
# 781/781 [==============================] - 90s 116ms/step - loss: 0.3567 - acc: 0.8682 - val_loss: 0.3532 - val_acc: 0.8701
#
# Epoch 00010: val_loss improved from 0.37983 to 0.35322, saving model to models6/rnn_lstm.h5
# Epoch 11/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3558 - acc: 0.8694 - val_loss: 0.3760 - val_acc: 0.8644
#
# Epoch 00011: val_loss did not improve from 0.35322
# Epoch 12/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3370 - acc: 0.8754 - val_loss: 0.3946 - val_acc: 0.8549
#
# Epoch 00012: val_loss did not improve from 0.35322
# Epoch 13/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3339 - acc: 0.8766 - val_loss: 0.3398 - val_acc: 0.8745
#
# Epoch 00013: val_loss improved from 0.35322 to 0.33984, saving model to models6/rnn_lstm.h5
# Epoch 14/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3199 - acc: 0.8822 - val_loss: 0.3432 - val_acc: 0.8739
#
# Epoch 00014: val_loss did not improve from 0.33984
# Epoch 15/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3108 - acc: 0.8845 - val_loss: 0.3317 - val_acc: 0.8793
#
# Epoch 00015: val_loss improved from 0.33984 to 0.33167, saving model to models6/rnn_lstm.h5
# Epoch 16/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3331 - acc: 0.8776 - val_loss: 0.3511 - val_acc: 0.8702
#
# Epoch 00016: val_loss did not improve from 0.33167
# Epoch 17/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3107 - acc: 0.8849 - val_loss: 0.3269 - val_acc: 0.8810
#
# Epoch 00017: val_loss improved from 0.33167 to 0.32691, saving model to models6/rnn_lstm.h5
# Epoch 18/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3090 - acc: 0.8858 - val_loss: 0.3330 - val_acc: 0.8780
#
# Epoch 00018: val_loss did not improve from 0.32691
# Epoch 19/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.3021 - acc: 0.8885 - val_loss: 0.3203 - val_acc: 0.8806
#
# Epoch 00019: val_loss improved from 0.32691 to 0.32027, saving model to models6/rnn_lstm.h5
# Epoch 20/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2879 - acc: 0.8921 - val_loss: 0.3194 - val_acc: 0.8801
#
# Epoch 00020: val_loss improved from 0.32027 to 0.31943, saving model to models6/rnn_lstm.h5
# Epoch 21/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2801 - acc: 0.8964 - val_loss: 0.3067 - val_acc: 0.8851
#
# Epoch 00021: val_loss improved from 0.31943 to 0.30673, saving model to models6/rnn_lstm.h5
# Epoch 22/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2745 - acc: 0.8988 - val_loss: 0.3099 - val_acc: 0.8847
#
# Epoch 00022: val_loss did not improve from 0.30673
# Epoch 23/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2654 - acc: 0.9011 - val_loss: 0.3002 - val_acc: 0.8889
#
# Epoch 00023: val_loss improved from 0.30673 to 0.30018, saving model to models6/rnn_lstm.h5
# Epoch 24/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2680 - acc: 0.8998 - val_loss: 0.3064 - val_acc: 0.8901
#
# Epoch 00024: val_loss did not improve from 0.30018
# Epoch 25/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2586 - acc: 0.9039 - val_loss: 0.2994 - val_acc: 0.8881
#
# Epoch 00025: val_loss improved from 0.30018 to 0.29944, saving model to models6/rnn_lstm.h5
# Epoch 26/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2554 - acc: 0.9043 - val_loss: 0.2933 - val_acc: 0.8928
#
# Epoch 00026: val_loss improved from 0.29944 to 0.29328, saving model to models6/rnn_lstm.h5
# Epoch 27/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2479 - acc: 0.9081 - val_loss: 0.2920 - val_acc: 0.8945
#
# Epoch 00027: val_loss improved from 0.29328 to 0.29199, saving model to models6/rnn_lstm.h5
# Epoch 28/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2492 - acc: 0.9073 - val_loss: 0.2897 - val_acc: 0.8941
#
# Epoch 00028: val_loss improved from 0.29199 to 0.28973, saving model to models6/rnn_lstm.h5
# Epoch 29/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2419 - acc: 0.9086 - val_loss: 0.3055 - val_acc: 0.8865
#
# Epoch 00029: val_loss did not improve from 0.28973
# Epoch 30/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2382 - acc: 0.9118 - val_loss: 0.2893 - val_acc: 0.8948
#
# Epoch 00030: val_loss improved from 0.28973 to 0.28933, saving model to models6/rnn_lstm.h5
# Epoch 31/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2354 - acc: 0.9140 - val_loss: 0.3104 - val_acc: 0.8878
#
# Epoch 00031: val_loss did not improve from 0.28933
# Epoch 32/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2381 - acc: 0.9115 - val_loss: 0.2855 - val_acc: 0.8970
#
# Epoch 00032: val_loss improved from 0.28933 to 0.28550, saving model to models6/rnn_lstm.h5
# Epoch 33/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2276 - acc: 0.9146 - val_loss: 0.2770 - val_acc: 0.8984
#
# Epoch 00033: val_loss improved from 0.28550 to 0.27699, saving model to models6/rnn_lstm.h5
# Epoch 34/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2279 - acc: 0.9145 - val_loss: 0.2826 - val_acc: 0.8995
#
# Epoch 00034: val_loss did not improve from 0.27699
# Epoch 35/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2396 - acc: 0.9117 - val_loss: 0.2775 - val_acc: 0.8987
#
# Epoch 00035: val_loss did not improve from 0.27699
# Epoch 36/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2224 - acc: 0.9171 - val_loss: 0.2828 - val_acc: 0.8984
#
# Epoch 00036: val_loss did not improve from 0.27699
# Epoch 37/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2149 - acc: 0.9197 - val_loss: 0.2720 - val_acc: 0.9010
#
# Epoch 00037: val_loss improved from 0.27699 to 0.27200, saving model to models6/rnn_lstm.h5
# Epoch 38/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2102 - acc: 0.9224 - val_loss: 0.2762 - val_acc: 0.9002
#
# Epoch 00038: val_loss did not improve from 0.27200
# Epoch 39/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2093 - acc: 0.9211 - val_loss: 0.2705 - val_acc: 0.9034
#
# Epoch 00039: val_loss improved from 0.27200 to 0.27046, saving model to models6/rnn_lstm.h5
# Epoch 40/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2038 - acc: 0.9234 - val_loss: 0.2873 - val_acc: 0.8960
#
# Epoch 00040: val_loss did not improve from 0.27046
# Epoch 41/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2022 - acc: 0.9243 - val_loss: 0.2706 - val_acc: 0.9042
#
# Epoch 00041: val_loss did not improve from 0.27046
# Epoch 42/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.2000 - acc: 0.9254 - val_loss: 0.2755 - val_acc: 0.9019
#
# Epoch 00042: val_loss did not improve from 0.27046
# Epoch 43/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1971 - acc: 0.9258 - val_loss: 0.2747 - val_acc: 0.9027
#
# Epoch 00043: val_loss did not improve from 0.27046
# Epoch 44/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1914 - acc: 0.9288 - val_loss: 0.2616 - val_acc: 0.9050
#
# Epoch 00044: val_loss improved from 0.27046 to 0.26162, saving model to models6/rnn_lstm.h5
# Epoch 45/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1870 - acc: 0.9310 - val_loss: 0.2721 - val_acc: 0.9026
#
# Epoch 00045: val_loss did not improve from 0.26162
# Epoch 46/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1859 - acc: 0.9308 - val_loss: 0.2731 - val_acc: 0.9056
#
# Epoch 00046: val_loss did not improve from 0.26162
# Epoch 47/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1817 - acc: 0.9324 - val_loss: 0.2751 - val_acc: 0.9030
#
# Epoch 00047: val_loss did not improve from 0.26162
# Epoch 48/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1803 - acc: 0.9320 - val_loss: 0.2722 - val_acc: 0.9037
#
# Epoch 00048: val_loss did not improve from 0.26162
# Epoch 49/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1787 - acc: 0.9336 - val_loss: 0.2732 - val_acc: 0.9043
#
# Epoch 00049: val_loss did not improve from 0.26162
# Epoch 50/50
# 781/781 [==============================] - 91s 116ms/step - loss: 0.1796 - acc: 0.9331 - val_loss: 0.2686 - val_acc: 0.9053
#
# Epoch 00050: val_loss did not improve from 0.26162

# %%
from google.colab import files

print(best_model)
print("Best Stats")
print("==========")
print("accuracy      : {}".format(best_accuracy))
print("batch size    : {}".format(best_batch_size))
print("epochs        : {}".format(best_epochs))
print("optimizer     : {}".format(best_optimizer))
print("learning rate : {}".format(best_learning_rate))
print("node size     : {}".format(best_node_size))

filepath = "models/rnn_lstm_best.h5"
files.download(filepath)
