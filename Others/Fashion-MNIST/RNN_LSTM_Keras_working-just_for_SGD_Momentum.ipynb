# %%
# !mkdir models

# %%
# !ls

# %%
# %matplotlib inline

from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras import optimizers

from keras.models import Model
from keras.layers import Input, Dense, TimeDistributed, LSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

import cv2
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


def img_resize(org_imgs, target_size):
  x_imgs = []
  for i in range(0,org_imgs.shape[0]):
    x_img = cv2.resize(org_imgs[i], dsize=(target_size, target_size), interpolation=cv2.INTER_CUBIC)
    x_imgs.append(x_img)
  return np.array(x_imgs)


def plot_model(model_details):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_details.history['loss'])+1),model_details.history['loss'])
    axs[1].plot(range(1,len(model_details.history['val_loss'])+1),model_details.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_details.history['loss'])+1),len(model_details.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_details.history['acc'])+1),model_details.history['acc'])
    axs[0].plot(range(1,len(model_details.history['val_acc'])+1),model_details.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_details.history['acc'])+1),len(model_details.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()
    
    
# Training parameters.
batch_sizes = [64]
num_epochs = [50]
learning_rates = [0.05,0.01]
optimizers_name = ['sgd']
num_classes = 10
node_sizes = [128]

# The data, shuffled and split between train and test sets.
(images, labels), (_, _) = fashion_mnist.load_data()

images_zoomed_in = img_resize(images, 48)
images_zoomed_in = images_zoomed_in.reshape(images_zoomed_in.shape[0], images_zoomed_in.shape[1], images_zoomed_in.shape[2], 1).astype('float32')

x_train = images_zoomed_in[0:50000]
x_test = images_zoomed_in[50000:60000]

y_train = labels[0:50000]
y_test = labels[50000:60000]


# x_train -= np.mean(x_train)
# x_test -= np.mean(x_train)

# x_train /= np.std(x_train)
# x_test /= np.std(x_train)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


TRAIN_DATA_SIZE = x_train.shape[0]
TEST_DATA_SIZE = x_test.shape[0]

#TRAIN_BATCH_SIZE = 20
#TEST_BATCH_SIZE = 10

#train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
#test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)


# Converts class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

train_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
train_gen.fit(x_train)
#train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

test_gen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)
test_gen.fit(x_train)
#test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

#row, col, pixel = x_train.shape[1:]


best_model = None
best_accuracy = 0
best_batch_size = 0
best_epochs = 0
best_optimizer = ''
best_learning_rate = 0
best_node_size = 0
# Out:
# /home/ryantsan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (50000, 48, 48, 1)
# 50000 train samples
# 10000 test samples

# %%
for batch_size in batch_sizes:
  for epochs in num_epochs:
    for optimizer_name in optimizers_name:
      for learning_rate in learning_rates:
        for node_size in node_sizes:
            print("==================")
            print("batch size    : {}".format(batch_size))
            print("epochs        : {}".format(epochs))
            print("optimizer     : {}".format(optimizer_name))
            print("learning rate : {}".format(learning_rate))
            print("node size     : {}".format(node_size))

            if optimizer_name == 'adam':
              optimizer = optimizers.Adam(lr=learning_rate)
            elif optimizer_name == 'rmsprop':
              optimizer = optimizers.RMSprop(lr=learning_rate)
            elif optimizer_name == 'sgd':
              optimizer = optimizers.SGD(lr=learning_rate, momentum=0.9,nesterov=True)

            # Embedding dimensions.
            row_hidden = node_size
            col_hidden = node_size

            
            TRAIN_BATCH_SIZE = batch_size
            TEST_BATCH_SIZE = (batch_size)
            TEST_BATCH_SIZE
            
            train_step = int(TRAIN_DATA_SIZE/TRAIN_BATCH_SIZE)
            test_step = int(TEST_DATA_SIZE/TEST_BATCH_SIZE)
            
            train_batches = train_gen.flow(x_train, y_train, batch_size=TRAIN_BATCH_SIZE, shuffle=False, seed=10)

            test_batches = test_gen.flow(x_test, y_test, batch_size=TEST_BATCH_SIZE, shuffle=False, seed=10)

            row, col, pixel = x_train.shape[1:]
            
            
            # 4D input.
            x = Input(shape=(row, col, pixel))

            # Encodes a row of pixels using TimeDistributed Wrapper.
            encoded_rows = TimeDistributed(LSTM(row_hidden))(x)

            # Encodes columns of encoded rows.
            encoded_columns = LSTM(col_hidden)(encoded_rows)

            # Final predictions and model.
            prediction = Dense(num_classes, activation='softmax')(encoded_columns)

            model = Model(x, prediction)
            model.compile(loss='categorical_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])

            


            # Training.
            # model.fit(x_train, y_train,
            #           batch_size=batch_size,
            #           epochs=epochs,
            #           verbose=1,
            #           validation_data=(x_test, y_test))
            model_file_name = "models/rnn_lstm_{}_{}_{}NMom_{}_{}.h5" . format(batch_size, epochs, optimizer_name, learning_rate, node_size)
            checkpoint = ModelCheckpoint(model_file_name, monitor='val_loss', verbose=0, save_best_only= True, mode='auto')

            best_model_file_name = "models/rnn_lstm.h5"
            best_checkpoint = ModelCheckpoint(best_model_file_name, monitor='val_loss', verbose=1, save_best_only= True, mode='auto')
       
            h = model.fit_generator(train_batches, steps_per_epoch=train_step, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], validation_steps=test_step, epochs=epochs, verbose=1)
            #h = model.fit_generator(train_batches, validation_data=test_batches, callbacks=[checkpoint, best_checkpoint], verbose=1)
  
            plot_model(h)
# Out:
# ==================
# batch size    : 64
# epochs        : 30
# optimizer     : sgd
# learning rate : 0.001
# node size     : 128
#
# Epoch 00001: val_loss improved from inf to 2.01101, saving model to models/rnn_lstm.h5
#
# Epoch 00002: val_loss improved from 2.01101 to 1.37712, saving model to models/rnn_lstm.h5
#
# Epoch 00003: val_loss improved from 1.37712 to 1.16649, saving model to models/rnn_lstm.h5
#
# Epoch 00004: val_loss improved from 1.16649 to 0.93594, saving model to models/rnn_lstm.h5
#
# Epoch 00005: val_loss improved from 0.93594 to 0.74716, saving model to models/rnn_lstm.h5
#
# Epoch 00006: val_loss improved from 0.74716 to 0.65048, saving model to models/rnn_lstm.h5
#
# Epoch 00007: val_loss improved from 0.65048 to 0.59035, saving model to models/rnn_lstm.h5
#
# Epoch 00008: val_loss did not improve from 0.59035
#
# Epoch 00009: val_loss did not improve from 0.59035
#
# Epoch 00010: val_loss improved from 0.59035 to 0.49368, saving model to models/rnn_lstm.h5
#
# Epoch 00011: val_loss improved from 0.49368 to 0.48678, saving model to models/rnn_lstm.h5
#
# Epoch 00012: val_loss improved from 0.48678 to 0.46963, saving model to models/rnn_lstm.h5
#
# Epoch 00013: val_loss improved from 0.46963 to 0.45140, saving model to models/rnn_lstm.h5
#
# Epoch 00014: val_loss improved from 0.45140 to 0.44072, saving model to models/rnn_lstm.h5
#
# Epoch 00015: val_loss improved from 0.44072 to 0.43563, saving model to models/rnn_lstm.h5
#
# Epoch 00016: val_loss improved from 0.43563 to 0.42017, saving model to models/rnn_lstm.h5
#
# Epoch 00017: val_loss improved from 0.42017 to 0.41505, saving model to models/rnn_lstm.h5
#
# Epoch 00018: val_loss improved from 0.41505 to 0.39826, saving model to models/rnn_lstm.h5
#
# Epoch 00019: val_loss did not improve from 0.39826
#
# Epoch 00020: val_loss improved from 0.39826 to 0.39062, saving model to models/rnn_lstm.h5
#
# Epoch 00021: val_loss did not improve from 0.39062
#
# Epoch 00022: val_loss improved from 0.39062 to 0.37811, saving model to models/rnn_lstm.h5
#
# Epoch 00023: val_loss improved from 0.37811 to 0.36912, saving model to models/rnn_lstm.h5
#
# Epoch 00024: val_loss did not improve from 0.36912
#
# Epoch 00025: val_loss did not improve from 0.36912
#
# Epoch 00026: val_loss did not improve from 0.36912
#
# Epoch 00027: val_loss did not improve from 0.36912
#
# Epoch 00028: val_loss did not improve from 0.36912
#
# Epoch 00029: val_loss improved from 0.36912 to 0.35408, saving model to models/rnn_lstm.h5
#
# Epoch 00030: val_loss improved from 0.35408 to 0.34443, saving model to models/rnn_lstm.h5
# ==================
# batch size    : 64
# epochs        : 30
# optimizer     : sgd
# learning rate : 0.01
# node size     : 128
#
# Epoch 00001: val_loss improved from inf to 0.79284, saving model to models/rnn_lstm.h5
#
# Epoch 00002: val_loss improved from 0.79284 to 0.53841, saving model to models/rnn_lstm.h5
#
# Epoch 00003: val_loss improved from 0.53841 to 0.49773, saving model to models/rnn_lstm.h5
#
# Epoch 00004: val_loss improved from 0.49773 to 0.42671, saving model to models/rnn_lstm.h5
#
# Epoch 00005: val_loss improved from 0.42671 to 0.41266, saving model to models/rnn_lstm.h5
#
# Epoch 00006: val_loss did not improve from 0.41266
#
# Epoch 00007: val_loss improved from 0.41266 to 0.38204, saving model to models/rnn_lstm.h5
#
# Epoch 00008: val_loss improved from 0.38204 to 0.37080, saving model to models/rnn_lstm.h5
#
# Epoch 00009: val_loss improved from 0.37080 to 0.35733, saving model to models/rnn_lstm.h5
#
# Epoch 00010: val_loss improved from 0.35733 to 0.34166, saving model to models/rnn_lstm.h5
#
# Epoch 00011: val_loss did not improve from 0.34166
#
# Epoch 00012: val_loss did not improve from 0.34166
#
# Epoch 00013: val_loss improved from 0.34166 to 0.31305, saving model to models/rnn_lstm.h5
#
# Epoch 00014: val_loss did not improve from 0.31305
#
# Epoch 00015: val_loss improved from 0.31305 to 0.31092, saving model to models/rnn_lstm.h5
#
# Epoch 00016: val_loss improved from 0.31092 to 0.30237, saving model to models/rnn_lstm.h5
#
# Epoch 00017: val_loss did not improve from 0.30237
#
# Epoch 00018: val_loss improved from 0.30237 to 0.28438, saving model to models/rnn_lstm.h5
#
# Epoch 00019: val_loss did not improve from 0.28438
#
# Epoch 00020: val_loss improved from 0.28438 to 0.28273, saving model to models/rnn_lstm.h5
#
# Epoch 00021: val_loss did not improve from 0.28273
#
# Epoch 00022: val_loss did not improve from 0.28273
#
# Epoch 00023: val_loss improved from 0.28273 to 0.27714, saving model to models/rnn_lstm.h5
#
# Epoch 00024: val_loss did not improve from 0.27714
#
# Epoch 00025: val_loss improved from 0.27714 to 0.26656, saving model to models/rnn_lstm.h5
#
# Epoch 00026: val_loss improved from 0.26656 to 0.26225, saving model to models/rnn_lstm.h5
#
# Epoch 00027: val_loss did not improve from 0.26225
#
# Epoch 00028: val_loss did not improve from 0.26225
#
# Epoch 00029: val_loss improved from 0.26225 to 0.26174, saving model to models/rnn_lstm.h5
#
# Epoch 00030: val_loss did not improve from 0.26174

# %%
from google.colab import files

print(best_model)
print("Best Stats")
print("==========")
print("accuracy      : {}".format(best_accuracy))
print("batch size    : {}".format(best_batch_size))
print("epochs        : {}".format(best_epochs))
print("optimizer     : {}".format(best_optimizer))
print("learning rate : {}".format(best_learning_rate))
print("node size     : {}".format(best_node_size))

filepath = "models/rnn_lstm_best.h5"
files.download(filepath)
