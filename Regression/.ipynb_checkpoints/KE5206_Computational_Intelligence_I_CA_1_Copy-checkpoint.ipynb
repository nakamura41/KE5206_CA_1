# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import pickle
import operator
import folium
from ggplot import *

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, median_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from neupy import algorithms, estimators, environment, layers, plots, init
from xgboost import XGBClassifier
from xgboost import plot_importance

from RBFN import RBFN
from ensemble import AveragedNetwork, StackedNetwork

sns.set(style="whitegrid")
# Out:
# /Users/davidleonardi/anaconda3/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /Users/davidleonardi/anaconda3/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /Users/davidleonardi/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Load & Merge Data [Note: raw datafiles are stored in /Data]

# %%
properties = pd.read_csv('Data/properties_2016.csv', header=0, encoding='utf-8')
train = pd.read_csv('Data/train_2016_v2.csv', parse_dates=["transactiondate"], header=0, encoding='utf-8')

merged_df = pd.merge(train,properties,on="parcelid",how="left")

print("Shape Of Dataset: ", merged_df.shape)

# %% [markdown]
# ### Save Merged Data

# %%
merged_df.to_csv("Data/merged_2016.csv", index=False)

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Load Data

# %%
merged_df = pd.read_csv("Data/merged_2016.csv")

# %% [markdown]
# ## Describe Data

# %%
merged_df.describe().to_csv("data_desc.csv")
merged_df.describe()
# Out:
#            parcelid      logerror  airconditioningtypeid  \
# count  9.027500e+04  90275.000000           28781.000000
# mean   1.298466e+07      0.011457               1.816372
# std    2.504510e+06      0.161079               2.974168
# min    1.071174e+07     -4.605000               1.000000
# 25%    1.155950e+07     -0.025300               1.000000
# 50%    1.254734e+07      0.006000               1.000000
# 75%    1.422755e+07      0.039200               1.000000
# max    1.629608e+08      4.737000              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                261.000000     43.000000  90275.000000  90275.000000
# mean                   7.229885    713.581395      2.279474      3.031869
# std                    2.716196    437.434198      1.004271      1.156436
# min                    2.000000    100.000000      0.000000      0.000000
# 25%                    7.000000    407.500000      2.000000      2.000000
# 50%                    7.000000    616.000000      2.000000      3.000000
# 75%                    7.000000    872.000000      3.000000      4.000000
# max                   21.000000   1555.000000     20.000000     16.000000
#
#        buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# count                 16.0           57364.000000       89093.000000
# mean                   4.0               5.565407           2.309216
# std                    0.0               1.900602           0.976172
# min                    4.0               1.000000           1.000000
# 25%                    4.0               4.000000           2.000000
# 50%                    4.0               7.000000           2.000000
# 75%                    4.0               7.000000           3.000000
# max                    4.0              12.000000          20.000000
#
#               ...           yardbuildingsqft26     yearbuilt  numberofstories  \
# count         ...                    95.000000  89519.000000     20570.000000
# mean          ...                   311.694737   1968.532870         1.440739
# std           ...                   346.354850     23.763475         0.544498
# min           ...                    18.000000   1885.000000         1.000000
# 25%           ...                   100.000000   1953.000000         1.000000
# 50%           ...                   159.000000   1970.000000         1.000000
# 75%           ...                   361.000000   1987.000000         2.000000
# max           ...                  1366.000000   2015.000000         4.000000
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# count                8.989500e+04       9.027400e+04         90275.0
# mean                 1.800934e+05       4.576726e+05          2015.0
# std                  2.091299e+05       5.548844e+05             0.0
# min                  1.000000e+02       2.200000e+01          2015.0
# 25%                  8.124500e+04       1.990232e+05          2015.0
# 50%                  1.320000e+05       3.428720e+05          2015.0
# 75%                  2.105345e+05       5.405890e+05          2015.0
# max                  9.948100e+06       2.775000e+07          2015.0
#
#        landtaxvaluedollarcnt      taxamount  taxdelinquencyyear  \
# count           9.027400e+04   90269.000000         1783.000000
# mean            2.783353e+05    5983.975927           13.402692
# std             4.004955e+05    6838.876956            2.715966
# min             2.200000e+01      49.080000            6.000000
# 25%             8.222800e+04    2872.830000           13.000000
# 50%             1.929700e+05    4542.750000           14.000000
# 75%             3.454195e+05    6901.090000           15.000000
# max             2.450000e+07  321936.090000           99.000000
#
#        censustractandblock
# count         8.967000e+04
# mean          6.049151e+13
# std           2.046605e+11
# min           6.037101e+13
# 25%           6.037320e+13
# 50%           6.037615e+13
# 75%           6.059042e+13
# max           6.111009e+13
#
# [8 rows x 54 columns]

# %% [markdown]
# ### Display Features Data Type

# %%
pd.options.display.max_rows = 65

dtype_df = merged_df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df
# Out:
#                            Count Column Type
# 0                       parcelid       int64
# 1                       logerror     float64
# 2                transactiondate      object
# 3          airconditioningtypeid     float64
# 4       architecturalstyletypeid     float64
# 5                   basementsqft     float64
# 6                    bathroomcnt     float64
# 7                     bedroomcnt     float64
# 8            buildingclasstypeid     float64
# 9          buildingqualitytypeid     float64
# 10             calculatedbathnbr     float64
# 11                    decktypeid     float64
# 12      finishedfloor1squarefeet     float64
# 13  calculatedfinishedsquarefeet     float64
# 14          finishedsquarefeet12     float64
# 15          finishedsquarefeet13     float64
# 16          finishedsquarefeet15     float64
# 17          finishedsquarefeet50     float64
# 18           finishedsquarefeet6     float64
# 19                          fips     float64
# 20                  fireplacecnt     float64
# 21                   fullbathcnt     float64
# 22                  garagecarcnt     float64
# 23               garagetotalsqft     float64
# 24                hashottuborspa      object
# 25         heatingorsystemtypeid     float64
# 26                      latitude     float64
# 27                     longitude     float64
# 28             lotsizesquarefeet     float64
# 29                       poolcnt     float64
# 30                   poolsizesum     float64
# 31                  pooltypeid10     float64
# 32                   pooltypeid2     float64
# 33                   pooltypeid7     float64
# 34     propertycountylandusecode      object
# 35         propertylandusetypeid     float64
# 36            propertyzoningdesc      object
# 37        rawcensustractandblock     float64
# 38                  regionidcity     float64
# 39                regionidcounty     float64
# 40          regionidneighborhood     float64
# 41                   regionidzip     float64
# 42                       roomcnt     float64
# 43                   storytypeid     float64
# 44           threequarterbathnbr     float64
# 45        typeconstructiontypeid     float64
# 46                       unitcnt     float64
# 47            yardbuildingsqft17     float64
# 48            yardbuildingsqft26     float64
# 49                     yearbuilt     float64
# 50               numberofstories     float64
# 51                 fireplaceflag      object
# 52    structuretaxvaluedollarcnt     float64
# 53             taxvaluedollarcnt     float64
# 54                assessmentyear     float64
# 55         landtaxvaluedollarcnt     float64
# 56                     taxamount     float64
# 57            taxdelinquencyflag      object
# 58            taxdelinquencyyear     float64
# 59           censustractandblock     float64

# %% [markdown]
# ### Show Frst Few Rows of Data

# %%
merged_df.head(3).transpose()
# Out:
#                                         0            1            2
# parcelid                         11016594     14366692     12098116
# logerror                           0.0276      -0.1684       -0.004
# transactiondate                2016-01-01   2016-01-01   2016-01-01
# airconditioningtypeid                   1          NaN            1
# architecturalstyletypeid              NaN          NaN          NaN
# basementsqft                          NaN          NaN          NaN
# bathroomcnt                             2          3.5            3
# bedroomcnt                              3            4            2
# buildingclasstypeid                   NaN          NaN          NaN
# buildingqualitytypeid                   4          NaN            4
# calculatedbathnbr                       2          3.5            3
# decktypeid                            NaN          NaN          NaN
# finishedfloor1squarefeet              NaN          NaN          NaN
# calculatedfinishedsquarefeet         1684         2263         2217
# finishedsquarefeet12                 1684         2263         2217
# finishedsquarefeet13                  NaN          NaN          NaN
# finishedsquarefeet15                  NaN          NaN          NaN
# finishedsquarefeet50                  NaN          NaN          NaN
# finishedsquarefeet6                   NaN          NaN          NaN
# fips                                 6037         6059         6037
# fireplacecnt                          NaN          NaN          NaN
# fullbathcnt                             2            3            3
# garagecarcnt                          NaN            2          NaN
# garagetotalsqft                       NaN          468          NaN
# hashottuborspa                        NaN          NaN          NaN
# heatingorsystemtypeid                   2          NaN            2
# latitude                       3.4281e+07  3.36681e+07  3.41363e+07
# longitude                    -1.18489e+08 -1.17678e+08 -1.18175e+08
# lotsizesquarefeet                    7528         3643        11423
# poolcnt                               NaN          NaN          NaN
# poolsizesum                           NaN          NaN          NaN
# pooltypeid10                          NaN          NaN          NaN
# pooltypeid2                           NaN          NaN          NaN
# pooltypeid7                           NaN          NaN          NaN
# propertycountylandusecode            0100            1         0100
# propertylandusetypeid                 261          261          261
# propertyzoningdesc                   LARS          NaN         PSR6
# rawcensustractandblock        6.03711e+07  6.05905e+07  6.03746e+07
# regionidcity                        12447        32380        47019
# regionidcounty                       3101         1286         3101
# regionidneighborhood                31817          NaN       275411
# regionidzip                         96370        96962        96293
# roomcnt                                 0            0            0
# storytypeid                           NaN          NaN          NaN
# threequarterbathnbr                   NaN            1          NaN
# typeconstructiontypeid                NaN          NaN          NaN
# unitcnt                                 1          NaN            1
# yardbuildingsqft17                    NaN          NaN          NaN
# yardbuildingsqft26                    NaN          NaN          NaN
# yearbuilt                            1959         2014         1940
# numberofstories                       NaN          NaN          NaN
# fireplaceflag                         NaN          NaN          NaN
# structuretaxvaluedollarcnt         122754       346458        61994
# taxvaluedollarcnt                  360170       585529       119906
# assessmentyear                       2015         2015         2015
# landtaxvaluedollarcnt              237416       239071        57912
# taxamount                         6735.88        10153      11484.5
# taxdelinquencyflag                    NaN          NaN          NaN
# taxdelinquencyyear                    NaN          NaN          NaN
# censustractandblock           6.03711e+13          NaN  6.03746e+13

# %% [markdown]
# ### Standardize longitude and latitude

# %%
merged_df['longitude'] = merged_df['longitude'] / 1000000
merged_df['latitude'] = merged_df['latitude'] / 1000000

# %% [markdown]
# ## Geospatial Plot

# %%
n_clusters = round(merged_df.regionidzip.unique().shape[0] / 2)

print("number of clusters: {}".format(n_clusters))
# Out:
# number of clusters: 194

# %%
from sklearn.cluster import MiniBatchKMeans

geographical_df = merged_df.loc[:, ('latitude', 'longitude', 'logerror')]
geographical_df = geographical_df.dropna(subset=['latitude','longitude'], axis=0)

kmeans = MiniBatchKMeans(n_clusters=n_clusters, batch_size=1000).fit(geographical_df[['latitude','longitude']])
geographical_df.loc[:, 'label'] = kmeans.labels_

geo_map = folium.Map(location=[geographical_df['latitude'].mean(), geographical_df['longitude'].mean()], zoom_start=9)

for label in kmeans.cluster_centers_:
    location = [label[0], label[1]]
    folium.Marker(location=location).add_to(geo_map)

geo_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Plot Histogram of Target Class (logerror)

# %%
plt.figure(figsize=(12,8))
sns.distplot(merged_df['logerror'], bins=50, kde=False)
plt.xlabel('logerror', fontsize=12)
plt.show()

# %% [markdown]
# ### Plot Histogram of absolute logerror

# %%
merged_df['abs_logerror'] = abs(merged_df['logerror'])

plt.figure(figsize=(12,8))
sns.distplot(merged_df['abs_logerror'], bins=50, kde=False)
plt.xlabel('abs_logerror', fontsize=12)
plt.show()

# %% [markdown]
# ### Plot the target class (logerror of Zillow)

# %%
plt.figure(figsize=(8,6))
plt.scatter(range(merged_df.shape[0]), np.sort(merged_df['logerror'].values))
plt.xlabel('index', fontsize=12)
plt.ylabel('logerror', fontsize=12)
plt.show()

# %% [markdown]
# This looks nice with some outliers at both the ends!

# %% [markdown]
# ## Continuous Variable

# %% [markdown]
# ### Histogram of Total Area (calculatedfinishedsquarefeet)

# %%
plt.hist(merged_df['calculatedfinishedsquarefeet'].dropna(), bins=12) 
plt.title("Total Area") 
plt.show()

# %% [markdown]
# ## Categorial Variable

# %% [markdown]
# ### Histogram of number of bathroom

# %%
merged_df['bathroomcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# ### Histogram of number of bedroom

# %%
merged_df['bedroomcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# ### Histogram of number of unit

# %%
merged_df['unitcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Compute the correlation matrix

# %%
corr = merged_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.8, center=0,
            square=True, linewidths=.8, cbar_kws={"shrink": .5})

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### Remove Outliers

# %% [markdown]
# Let us remove the outliers based on target class (logerror) and then do a histogram plot on the same.

# %%
merged_df = merged_df[merged_df['logerror'] < merged_df['logerror'].quantile(.99)]
merged_df = merged_df[merged_df['logerror'] > merged_df['logerror'].quantile(.01)]

plt.figure(figsize=(8,6))
plt.scatter(range(merged_df.shape[0]), np.sort(merged_df['logerror']))
plt.xlabel('index', fontsize=12)
plt.ylabel('logerror', fontsize=12)
plt.show()

# %% [markdown]
# #### Plot Histogram of Target Class (logerror) again

# %%
plt.figure(figsize=(12,8))
sns.distplot(merged_df['logerror'], bins=50, kde=False)
plt.xlabel('logerror', fontsize=12)
plt.show()

# %% [markdown]
# #### Plot Histogram of absolute logerror again

# %%
merged_df['abs_logerror'] = abs(merged_df['logerror'])

plt.figure(figsize=(12,8))
sns.distplot(merged_df['abs_logerror'], bins=50, kde=False)
plt.xlabel('abs_logerror', fontsize=12)
plt.show()

# %% [markdown]
# #### Remove Outlier based on Total Area

# %%
merged_df = merged_df[merged_df['calculatedfinishedsquarefeet'] < merged_df['calculatedfinishedsquarefeet'].quantile(.999)]

plt.hist(merged_df['calculatedfinishedsquarefeet'].dropna(), bins=12) 
plt.title("Total Area") 
plt.show()

# %% [markdown]
# #### Remove Outlier based on number of bathroom

# %%
merged_df = merged_df[merged_df['bathroomcnt'] < merged_df['bathroomcnt'].quantile(.999)]

merged_df['bathroomcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# #### Remove Outlier based on number of bedroom

# %%
merged_df = merged_df[merged_df['bedroomcnt'] < merged_df['bedroomcnt'].quantile(.999)]

merged_df['bedroomcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# #### Remove Outlier based on number of unit

# %%
merged_df = merged_df[merged_df['unitcnt'] < merged_df['unitcnt'].quantile(.999)]

merged_df['unitcnt'].dropna().value_counts().plot(kind="bar")

# %% [markdown]
# ### Missing values

# %%
missing_values_df = merged_df.isnull().sum(axis=0).reset_index()
missing_values_df.columns = ['column_name', 'missing_count']
missing_values_df['missing_ratio'] = missing_values_df['missing_count'] / merged_df.shape[0]

missing_values_df = missing_values_df[missing_values_df['missing_count'] > 0]
missing_values_df = missing_values_df.sort_values(by='missing_count')

ind = np.arange(missing_values_df.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, missing_values_df['missing_ratio'], color='blue')
ax.set_yticks(ind)
ax.set_yticklabels(missing_values_df['column_name'], rotation='horizontal')
ax.set_xlabel("Ratio of missing values")
ax.set_title("Ratio of missing values in each column")
plt.show()

# %% [markdown]
# #### Remove features with high degree of missing values

# %%
removed_columns_df = missing_values_df[missing_values_df['missing_ratio'] > 0.6]
removed_columns = removed_columns_df[removed_columns_df.columns[0]].tolist()

good_features_df = merged_df.drop(removed_columns, axis=1)

print("Removed Features")
removed_columns
# Out:
# Removed Features
# ['poolcnt',
#  'pooltypeid7',
#  'finishedsquarefeet15',
#  'taxdelinquencyflag',
#  'taxdelinquencyyear',
#  'hashottuborspa',
#  'pooltypeid10',
#  'numberofstories',
#  'finishedsquarefeet6',
#  'garagecarcnt',
#  'garagetotalsqft',
#  'fireplacecnt',
#  'buildingclasstypeid',
#  'finishedfloor1squarefeet',
#  'finishedsquarefeet50',
#  'threequarterbathnbr',
#  'yardbuildingsqft17',
#  'yardbuildingsqft26',
#  'architecturalstyletypeid',
#  'fireplaceflag',
#  'basementsqft',
#  'poolsizesum',
#  'typeconstructiontypeid',
#  'storytypeid',
#  'finishedsquarefeet13',
#  'pooltypeid2',
#  'decktypeid']

# %%
missing_values_df = good_features_df.isnull().sum(axis=0).reset_index()
missing_values_df.columns = ['column_name', 'missing_count']
missing_values_df['missing_ratio'] = missing_values_df['missing_count'] / merged_df.shape[0]

missing_values_df = missing_values_df[missing_values_df['missing_count'] > 0]
missing_values_df = missing_values_df.sort_values(by='missing_count')

ind = np.arange(missing_values_df.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, missing_values_df['missing_ratio'], color='blue')
ax.set_yticks(ind)
ax.set_yticklabels(missing_values_df['column_name'], rotation='horizontal')
ax.set_xlabel("Ratio of missing values")
ax.set_title("Ratio of missing values in each column")
plt.show()

# %% [markdown]
# #### Inspect manually -with data dictionary and domain knowledge - and confirm one by one if variable is to be discarded for high degree of missing values or they can be salvaged

# %%
#taxdelinquencyflag may be important, will fill it with "False" if it is not true
#'garage' and 'garage' features may be important for US and they are 0 if data is not filled in

merged_df['taxdelinquencyflag'] = merged_df['taxdelinquencyflag'].apply(lambda x: 1 if x == "Y" else 0)
merged_df['garagecarcnt'] = merged_df['garagecarcnt'].fillna(0)  #important to US people
merged_df['garagetotalsqft'] = merged_df['garagetotalsqft'].fillna(0) #important to US people

removed_columns = ['regionidneighborhood',
 'airconditioningtypeid',
 'numberofstories',
 'poolcnt',
 'pooltypeid7',
 'threequarterbathnbr',
 'fireplacecnt',
 'finishedsquarefeet50',
 'finishedfloor1squarefeet',
 'finishedsquarefeet15',
 'yardbuildingsqft17',
 'hashottuborspa',
 'taxdelinquencyyear',
 'pooltypeid2',
 'pooltypeid10',
 'poolsizesum',
 'decktypeid',
 'finishedsquarefeet6',
 'typeconstructiontypeid',
 'architecturalstyletypeid',
 'fireplaceflag',
 'yardbuildingsqft26',
 'storytypeid',
 'basementsqft',
 'finishedsquarefeet13',
 'buildingclasstypeid'
]

good_features_df = merged_df.drop(removed_columns, axis=1)

print("Removed features due to high degree of missing data and after manual inspection")
removed_columns
# Out:
# Removed features due to high degree of missing data and after manual inspection
# ['regionidneighborhood',
#  'airconditioningtypeid',
#  'numberofstories',
#  'poolcnt',
#  'pooltypeid7',
#  'threequarterbathnbr',
#  'fireplacecnt',
#  'finishedsquarefeet50',
#  'finishedfloor1squarefeet',
#  'finishedsquarefeet15',
#  'yardbuildingsqft17',
#  'hashottuborspa',
#  'taxdelinquencyyear',
#  'pooltypeid2',
#  'pooltypeid10',
#  'poolsizesum',
#  'decktypeid',
#  'finishedsquarefeet6',
#  'typeconstructiontypeid',
#  'architecturalstyletypeid',
#  'fireplaceflag',
#  'yardbuildingsqft26',
#  'storytypeid',
#  'basementsqft',
#  'finishedsquarefeet13',
#  'buildingclasstypeid']

# %% [markdown]
# #### Filter out Correlated Features for inspection (Not needed anymore since we remove manually)

# %%
def remove_correlation(input_dataset, threshold):
    dataset = input_dataset.copy(deep=True)
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) >= threshold:
                colname = corr_matrix.columns[i] # getting the name of column
                colname_j = corr_matrix.columns[j] # getting the name of the other column
                col_corr.add(colname)
                if colname in dataset.columns:
                    print("Remove '{}' due to it's similarity to '{}'".format(colname, colname_j))
                    del dataset[colname] # deleting the column from the dataset

    return dataset, col_corr

# %% [markdown]
# #### Inspect correlated Features manually and remove thems

# %%
# Remove 'num_bathroom' instead of 'calculatedbathnbr' as Zillow clarified that they used 'calculatedbathnbr' for their Zillow Est.
# Remove 'finishedsquarefeet12' due to it's similarity to 'calculatedfinishedsquarefeet' This is ok!! area_live_finished which is calculatedfinishedsquarefeet has more complete data!
# Remove 'fullbathcnt' due to it's similarity to 'bathroomcnt' --> Looks ok, the bathroomcnt have more data
# Remove 'rawcensustractandblock' due to it's similarity to 'fips'
# Remove 'landtaxvaluedollarcnt' due to it's similarity to 'taxvaluedollarcnt' --> Looks ok, Taxvaluedollarcnt has more infomration
# Remove 'taxamount' due to it's similarity to 'taxvaluedollarcnt'
# Remove 'censustractandblock' due to it's similarity to 'fips' 

removed_columns =[
    'bathroomcnt',
    'censustractandblock',
    'finishedsquarefeet12',
    'fullbathcnt',
    'landtaxvaluedollarcnt',
    'rawcensustractandblock',
    'taxamount'
]

good_features_df = good_features_df.drop(removed_columns, axis=1)

# %% [markdown]
# #### Further Feature Inspection

# %%
removed_columns = [
    "parcelid", #Removed Unique Ident
    "transactiondate", # Not vital for current problem
    "propertycountylandusecode", #1 hot encoded land use have more detailed information
    "propertyzoningdesc",  #1 hot encoded land use have more detailed information
    "fips", #the 1-hot encoded postal code has better information
    "assessmentyear", # same information  #### LOOK AT it after new plots!
]

good_features_df = good_features_df.drop(removed_columns, axis=1)

# %% [markdown]
# ## Construct Data

# %% [markdown]
# ### Impute several missing value (N/A) with zero (0) or special value if applicable

# %%
good_features_df['heatingorsystemtypeid'] = good_features_df['heatingorsystemtypeid'].fillna(13)  #Fill as 13 which is "None" category in data_dictu

# %% [markdown]
# ### Impute the rest of missing value (N/A) with Mean value

# %%
good_features_df = good_features_df.fillna(good_features_df.mean())

# %%
def train_validate_test_split(features, target, validate_size, test_size):
    x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = (validate_size + test_size))
    x_validate, x_test, y_validate, y_test = train_test_split(x_test, y_test, test_size = test_size / (validate_size + test_size))
    return x_train, x_validate, x_test, y_train, y_validate, y_test

# %%
def dataframe_split(dataframe, target_column, as_matrix=True):
    target = dataframe[target_column]
    features = dataframe.loc[:, dataframe.columns != target_column]
    if as_matrix:
        target = target.as_matrix()
        features = features.as_matrix()
    return features, target

# %% [markdown]
# ## Feature Importance Scores based on XGBoost

# %%
environment.reproducible()

target_column = 'logerror'

xgb_df = good_features_df.drop(['abs_logerror'], axis=1)

features, target = dataframe_split(xgb_df, target_column, as_matrix=False)

x_train, x_test, y_train, y_test = train_test_split(
    features,
    target.reshape((-1, 1)),
    test_size=0.3,
)
# Out:
# /Users/davidleonardi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
import xgboost as xgb

y_mean = np.mean(y_train)

xgb_params = {
    'eta': 0.037,
    'max_depth': 5,
    'subsample': 0.80,
    'objective': 'reg:linear',
    'eval_metric': 'mae',
    'lambda': 0.8,   
    'alpha': 0.4, 
    'base_score': y_mean,
    'silent': 1
}

dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test)

num_boost_rounds = 250

# train model
xgb_model = xgb.train(dict(xgb_params, silent=1), dtrain, num_boost_round=num_boost_rounds)

# %%
importance = xgb_model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1))

importance_df = pd.DataFrame(importance, columns=['feature', 'fscore'])

# Plot Feature Importance
plt.figure()
importance_df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(10, 10))

# %% [markdown]
# ## Integrate Data

# %%
environment.reproducible()

target_column = "logerror"

dropped_columns = [ 
    "regionidzip",
    "propertylandusetypeid", 
    "abs_logerror"
]

final_df = good_features_df.drop(dropped_columns, axis=1) #all dropping done at feature engineering section, 
features, target = dataframe_split(final_df, target_column)

x_train, x_validate, x_test, y_train, y_validate, y_test = train_validate_test_split(
    preprocessing.minmax_scale(features),
    preprocessing.minmax_scale(target.reshape((-1, 1))),
    validate_size=0.15, 
    test_size=0.15,
)

num_features = x_train.shape[1]
num_target = y_train.shape[1]

# %% [markdown]
# # Modeling

# %% [markdown]
# ## GRNN

# %%
grnn_model = algorithms.GRNN(std=0.3, verbose=True)
grnn_model.train(x_train, y_train)

with open('grnn.pickle', 'wb') as f:
    pickle.dump(grnn_model, f)
# Out:
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.3

# %% [markdown]
# ### Evaluate GRNN

# %%
y_predicted = grnn_model.predict(x_test)

print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_predicted)))
print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_predicted)))
print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.10911036803095683
# Mean Absolute Error (0=Best, 1=Worst): 0.07141211053105712
# Median Absolute Error (0=Best, 1=Worst): 0.043031113319592695

# %% [markdown]
# ### GRNN Residual Plot

# %%
sns.residplot(y_predicted.ravel(), y_test.ravel(), lowess=True)

# %% [markdown]
# There is no pattern on the residual plot, that means our model decently predict the target class, since,
#
# 1. they’re pretty symmetrically distributed, tending to cluster towards the middle of the plot
# 2. they’re clustered around the lower single digits of the y-axis (e.g., -0.4 and 0.6, not 30 or 150)
# 3. in general there aren’t clear patterns

# %% [markdown]
# ### Train GRNN model with important features based on XG Boosting

# %%
df = importance_df[importance_df['fscore'] > 120]

target_column = "logerror"
important_features = df['feature'].tolist()
important_features.append(target_column)

important_features_df = final_df.filter(items=important_features)

important_features_df.head(5)
# Out:
#    bedroomcnt  regionidcity  yearbuilt  lotsizesquarefeet  \
# 0         3.0       12447.0     1959.0             7528.0
# 2         2.0       47019.0     1940.0            11423.0
# 3         2.0       12447.0     1987.0            70859.0
# 5         4.0       29712.0     1982.0             2708.0
# 6         2.0       24174.0     1939.0             6677.0
#
#    structuretaxvaluedollarcnt   latitude  taxvaluedollarcnt  \
# 0                    122754.0  34.280990           360170.0
# 2                     61994.0  34.136312           119906.0
# 3                    171518.0  33.755800           244880.0
# 5                    880650.0  33.870089          2447951.0
# 6                     64549.0  33.899475           111521.0
#
#    calculatedfinishedsquarefeet   longitude  logerror
# 0                        1684.0 -118.488536    0.0276
# 2                        2217.0 -118.175032   -0.0040
# 3                         839.0 -118.309000    0.0218
# 5                        3067.0 -118.402768   -0.2705
# 6                        1297.0 -118.212720    0.0440

# %%
features, target = dataframe_split(important_features_df, target_column)

xg_x_train, xg_x_validate, xg_x_test, xg_y_train, xg_y_validate, xg_y_test = train_validate_test_split(
    preprocessing.minmax_scale(features),
    preprocessing.minmax_scale(target.reshape((-1, 1))),
    validate_size=0.15, 
    test_size=0.15,
)

num_features = xg_x_train.shape[1]
num_target = xg_y_train.shape[1]

### Test Neupy GRNN on our dataset
grnn_model = algorithms.GRNN(std=0.3, verbose=True)
grnn_model.train(xg_x_train, xg_y_train)
# Out:
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.3

# %% [markdown]
# ### Evaluate GRNN with important features

# %%
xg_y_predicted = grnn_model.predict(xg_x_test)

print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(xg_y_test, xg_y_predicted)))
print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(xg_y_test, xg_y_predicted)))
print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(xg_y_test, xg_y_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.11022334595804038
# Mean Absolute Error (0=Best, 1=Worst): 0.07190134408647834
# Median Absolute Error (0=Best, 1=Worst): 0.043960848522951845

# %% [markdown]
# ### GRNN Residual Plot

# %%
sns.residplot(xg_y_predicted.ravel() - xg_y_test.ravel(), xg_y_test.ravel(), lowess=True)

# %% [markdown]
# ### Grid search Cross Validation for GRNN
#
# We are iterating through GRNN parameter (std) to get the best model.

# %%
params = np.linspace(0.1, 0.9, 9)

best_rmse = 1
best_std = 0

for std in params:
    grnn = algorithms.GRNN(std=std, verbose=True)
    grnn.train(x_train, y_train)
    
    y_predicted = grnn.predict(x_validate)
    rmse = estimators.rmse(y_predicted, y_validate)
    print("RMSE {} for std {}".format(rmse, std))
    if rmse < best_rmse:
        best_rmse = rmse
        best_std = std
        
        with open('grnn.pickle', 'wb') as f:
            pickle.dump(grnn, f)

print("Best std = {} with RMSE = {}".format(best_std, best_rmse))
# Out:
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.1
#
# RMSE 0.11068600886907244 for std 0.1
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.2
#
# RMSE 0.10858903174628949 for std 0.2
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.30000000000000004
#
# RMSE 0.10846566476750122 for std 0.30000000000000004
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.4
#
# RMSE 0.10847317336363832 for std 0.4
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.5
#
# RMSE 0.10847395496885164 for std 0.5
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.6
#
# RMSE 0.10850764478055512 for std 0.6
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.7000000000000001
#
# RMSE 0.10853729005504038 for std 0.7000000000000001
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.8
#
# RMSE 0.10855663289142951 for std 0.8
#
# Main information
#
# [ALGORITHM] GRNN
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 1
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] std = 0.9
#
# RMSE 0.1085693962226766 for std 0.9
# Best std = 0.30000000000000004 with RMSE = 0.10846566476750122

# %% [markdown]
# ### Load saved GRNN model

# %%
with open('grnn.pickle', 'rb') as f:
    grnn_model = pickle.load(f)
    
    y_predicted = grnn_model.predict(x_test)

    print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_predicted)))
    print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_predicted)))
    print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.10853377396002016
# Mean Absolute Error (0=Best, 1=Worst): 0.06987624837732932
# Median Absolute Error (0=Best, 1=Worst): 0.04193646091103287

# %%
df_test = pd.DataFrame(np.concatenate((y_test, y_predicted), axis=1), columns={'actual_logerror', 'predicted_logerror'})
df_test.to_csv('grnn_prediction_result_best.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## Radial Basis Function Network

# %%
features, target = dataframe_split(final_df, target_column)

x_train, x_validate, x_test, y_train, y_validate, y_test = train_validate_test_split(
    preprocessing.minmax_scale(features),
    preprocessing.minmax_scale(target.reshape((-1, 1))),
    validate_size=0.15, 
    test_size=0.15,
)

num_features = x_train.shape[1]
num_target = y_train.shape[1]

rbfn_model = RBFN(input_shape = num_features, hidden_shape = num_features)
rbfn_model.train(x_train,y_train)

with open('rbfn.pickle', 'wb') as f:
    pickle.dump(rbfn_model, f)

# %% [markdown]
# ### Evaluate the model

# %%
with open('rbfn.pickle', 'rb') as f:
    rbfn_model = pickle.load(f)
    
    y_predicted = rbfn_model.predict(x_test)

    print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_predicted)))
    print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_predicted)))
    print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.13207516696581612
# Mean Absolute Error (0=Best, 1=Worst): 0.08897091801707437
# Median Absolute Error (0=Best, 1=Worst): 0.056625815327975226

# %% [markdown]
# ### Residual Plot

# %%
sns.residplot(y_predicted.ravel() - y_test.ravel(), y_test.ravel(), lowess=True)

# %% [markdown]
# ## Conjugate Gradient Neural Network with Hyperparameter Tuning

# %%
features, target = dataframe_split(final_df, target_column)

x_train, x_validate, x_test, y_train, y_validate, y_test = train_validate_test_split(
    preprocessing.minmax_scale(features),
    preprocessing.minmax_scale(target.reshape((-1, 1))),
    validate_size=0.15, 
    test_size=0.15,
)

num_features = x_train.shape[1]
num_target = y_train.shape[1]

best_step = 0
best_rmse = 1

steps = [0.001, 0.005, 0.01, 0.05, 0.1, 0.2]

for step in steps:
    cgnet = algorithms.ConjugateGradient(
        connection=[
            layers.Input(num_features),
            layers.Sigmoid(num_features * 2),
            layers.Sigmoid(num_target),
        ],
        step=step,
        search_method='golden',
        error='rmse',
        update_function='fletcher_reeves',
        show_epoch=25,
        verbose=True,
        addons=[algorithms.LinearSearch],
    )

    cgnet.train(x_train, y_train, x_validate, y_validate, epochs=50)

    plots.error_plot(cgnet)

    y_predicted = cgnet.predict(x_validate)
    rmse = estimators.rmse(y_predicted, y_validate)
    print("RMSE {} for step {}".format(rmse, step))
    if rmse < best_rmse:
        best_rmse = rmse
        best_step = step

        with open('cgnet.pickle', 'wb') as f:
            pickle.dump(cgnet, f)

print("Best step = {} with RMSE = {}".format(best_step, best_rmse))
# Out:
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.001
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.29 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10899 |     0.11024 |      962 ms |
# |          25 |      0.1085 |     0.10971 |       1 sec |
# |          50 |     0.10849 |      0.1097 |       1 sec |
# ---------------------------------------------------------
# RMSE 0.10969783473252259 for step 0.001
#
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.005
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.35 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10981 |     0.11107 |      944 ms |
# |          25 |     0.10851 |     0.10973 |      970 ms |
# |          50 |     0.10849 |     0.10969 |      759 ms |
# ---------------------------------------------------------
# RMSE 0.10968895471593938 for step 0.005
#
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.01
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.36 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10961 |     0.11078 |       1 sec |
# |          25 |     0.10853 |     0.10979 |       1 sec |
# |          50 |     0.10849 |      0.1097 |       1 sec |
# ---------------------------------------------------------
# RMSE 0.10969845131968944 for step 0.01
#
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.05
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.37 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10924 |     0.11038 |      867 ms |
# |          25 |      0.1085 |     0.10974 |      943 ms |
# |          50 |     0.10849 |     0.10969 |      827 ms |
# ---------------------------------------------------------
# RMSE 0.10969347035109164 for step 0.05
#
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.51 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10935 |     0.11045 |      772 ms |
# |          25 |     0.10849 |      0.1097 |       1 sec |
# |          50 |     0.10848 |     0.10969 |       1 sec |
# ---------------------------------------------------------
# RMSE 0.10968690527453291 for step 0.1
#
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.2
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.40 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 50
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10978 |     0.11091 |       1 sec |
# |          25 |     0.10849 |      0.1097 |      859 ms |
# |          50 |     0.10848 |      0.1097 |      908 ms |
# ---------------------------------------------------------
# RMSE 0.10969522250394102 for step 0.2
# Best step = 0.1 with RMSE = 0.10968690527453291

# %%
with open('cgnet.pickle', 'rb') as f:
    cgnet_model = pickle.load(f)
    
    y_predicted = cgnet_model.predict(x_test)

    print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_predicted)))
    print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_predicted)))
    print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_predicted)))
# Out:
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.29 seconds
# Root Mean Square Error (0=Best, 1=Worst): 0.1091066559360978
# Mean Absolute Error (0=Best, 1=Worst): 0.07091544490817432
# Median Absolute Error (0=Best, 1=Worst): 0.042487152654089894

# %% [markdown]
# ### Residual Plot

# %%
sns.residplot(y_predicted.ravel() - y_test.ravel(), y_test.ravel(), lowess=True)

# %% [markdown]
# ## Gradient Descent Network

# %%
class Exponential(init.Initializer):
    def __init__(self, scale=0.01):
        self.scale = scale

    def sample(self, shape):
        return np.random.exponential(self.scale, size=shape)

steps = [0.01, 0.05, 0.1, 0.2]

best_step = 0
best_rmse = 1

for step in steps:
    gdnet = algorithms.GradientDescent(
        [
            layers.Input(num_features),
            layers.Sigmoid(num_features * 2, weight=Exponential(scale=0.02)),
            layers.Sigmoid(num_target, weight=Exponential(scale=0.05)),
        ],
        verbose=True,
        step=step,
        show_epoch=25,
    )

    gdnet.train(x_train, y_train, x_validate, y_validate, epochs=100)

    plots.error_plot(gdnet)

    y_predicted = gdnet.predict(x_validate)
    rmse = estimators.rmse(y_predicted, y_validate)
    print("RMSE {} for step {}".format(rmse, step))
    if rmse < best_rmse:
        best_rmse = rmse
        best_step = step

        with open('gdnet.pickle', 'wb') as f:
            pickle.dump(gdnet, f)

print("Best step = {} with RMSE = {}".format(best_step, best_rmse))
# Out:
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.01
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.35 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 100
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |    0.097986 |     0.09771 |       37 ms |
# |          25 |    0.066191 |    0.066035 |       42 ms |
# |          50 |    0.042355 |    0.042428 |       36 ms |
# |          75 |    0.027938 |    0.028189 |       39 ms |
# |         100 |    0.020088 |    0.020428 |       45 ms |
# ---------------------------------------------------------
# RMSE 0.14292770320364767 for step 0.01
#
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.05
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.23 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 100
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |     0.10209 |    0.095957 |       48 ms |
# |          25 |    0.016624 |    0.016486 |       40 ms |
# |          50 |    0.012011 |    0.012307 |       41 ms |
# |          75 |    0.011865 |     0.01215 |       48 ms |
# |         100 |     0.01186 |     0.01214 |       46 ms |
# ---------------------------------------------------------
# RMSE 0.1101806307088452 for step 0.05
#
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.26 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 100
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |    0.082246 |    0.070366 |       52 ms |
# |          25 |    0.011956 |    0.012238 |       46 ms |
# |          50 |    0.011856 |    0.012136 |       41 ms |
# |          75 |    0.011856 |    0.012135 |       51 ms |
# |         100 |    0.011856 |    0.012135 |       46 ms |
# ---------------------------------------------------------
# RMSE 0.11015857411961091 for step 0.1
#
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.2
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.25 seconds
#
# Start training
#
# [TRAINING DATA] shapes: (39221, 18)
# [TEST DATA] shapes: (8405, 18)
# [TRAINING] Total epochs: 100
#
# ---------------------------------------------------------
# |    Epoch    |  Train err  |  Valid err  |    Time     |
# ---------------------------------------------------------
# |           1 |    0.088671 |    0.063247 |       50 ms |
# |          25 |    0.011855 |    0.012134 |       41 ms |
# |          50 |    0.011855 |    0.012134 |       42 ms |
# |          75 |    0.011855 |    0.012134 |       46 ms |
# |         100 |    0.011855 |    0.012134 |       40 ms |
# ---------------------------------------------------------
# RMSE 0.11015264100154457 for step 0.2
# Best step = 0.2 with RMSE = 0.11015264100154457

# %%
y_predicted = gdnet_model.predict(x_test)

print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_predicted)))
print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_predicted)))
print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.10909891141441017
# Mean Absolute Error (0=Best, 1=Worst): 0.0721315193192392
# Median Absolute Error (0=Best, 1=Worst): 0.0444308874261099

# %% [markdown]
# ### Residual Plot

# %%
sns.residplot(y_predicted.ravel() - y_test.ravel(), y_test.ravel(), lowess=True)

# %% [markdown]
# ## Ensembled Model using average method

# %%
f = open('grnn.pickle', 'rb')
grnn_model = pickle.load(f)

f = open('rbfn.pickle', 'rb')
rbfn_model = pickle.load(f)

f = open('cgnet.pickle', 'rb')
cgnet_model = pickle.load(f)

f = open('gdnet.pickle', 'rb')
gdnet_model = pickle.load(f)
# Out:
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.31 seconds
#
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.2
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.36 seconds

# %%
# ensemble = AveragedNetwork([grnn_model, rbfn_model, cgnet_model, gdnet_model])
ensemble = AveragedNetwork([grnn_model, cgnet_model, gdnet_model])

y_ensemble_predicted = ensemble.predict(x_test)

print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_ensemble_predicted)))
print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_ensemble_predicted)))
print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_ensemble_predicted)))
# Out:
# Root Mean Square Error (0=Best, 1=Worst): 0.10830501690705631
# Mean Absolute Error (0=Best, 1=Worst): 0.07077776802795965
# Median Absolute Error (0=Best, 1=Worst): 0.04287254073049723

# %%
with open('ensembled_network.pickle', 'wb') as f:
    pickle.dump(ensemble, f)

# %% [markdown]
# ### Residual Plot

# %%
sns.residplot(y_predicted.ravel() - y_test.ravel(), y_test.ravel(), lowess=True)

# %% [markdown]
# ## Ensembled Model using Stacking

# %%
f = open('grnn.pickle', 'rb')
grnn_model = pickle.load(f)

f = open('rbfn.pickle', 'rb')
rbfn_model = pickle.load(f)

f = open('cgnet.pickle', 'rb')
cgnet_model = pickle.load(f)

f = open('gdnet.pickle', 'rb')
gdnet_model = pickle.load(f)
# Out:
# Main information
#
# [ALGORITHM] ConjugateGradient
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.1
# [OPTION] train_end_signal = None
# [OPTION] error = rmse
# [OPTION] addons = ['LinearSearch']
# [OPTION] update_function = fletcher_reeves
# [OPTION] maxiter = 10
# [OPTION] search_method = golden
# [OPTION] tol = 0.1
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.29 seconds
#
# Main information
#
# [ALGORITHM] GradientDescent
#
# [OPTION] verbose = True
# [OPTION] epoch_end_signal = None
# [OPTION] show_epoch = 25
# [OPTION] shuffle_data = False
# [OPTION] step = 0.2
# [OPTION] train_end_signal = None
# [OPTION] error = mse
# [OPTION] addons = None
#
# [THEANO] Initializing Theano variables and functions.
# [THEANO] Initialization finished successfully. It took 0.21 seconds

# %%
features, target = dataframe_split(final_df, target_column)

x_train, x_test, y_train, y_test = train_test_split(
    preprocessing.minmax_scale(features),
    preprocessing.minmax_scale(target.reshape((-1, 1))),
    test_size=0.3,
)

num_features = x_train.shape[1]
num_target = y_train.shape[1]

ensemble = StackedNetwork([grnn_model, cgnet_model, gdnet_model])

ensemble.train(x_train, y_train, pre_train = True)

y_ensemble_predicted = ensemble.predict(x_test)

print("Root Mean Square Error (0=Best, 1=Worst): {}".format(estimators.rmse(y_test, y_ensemble_predicted)))
print("Mean Absolute Error (0=Best, 1=Worst): {}".format(mean_absolute_error(y_test, y_ensemble_predicted)))
print("Median Absolute Error (0=Best, 1=Worst): {}".format(median_absolute_error(y_test, y_ensemble_predicted)))
# Out:
# /Users/davidleonardi/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:1306: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Root Mean Square Error (0=Best, 1=Worst): 0.11050222988350958
# Mean Absolute Error (0=Best, 1=Worst): 0.07200030328470174
# Median Absolute Error (0=Best, 1=Worst): 0.04406491327158901

# %%
with open('ensembled_stacked_network.pickle', 'wb') as f:
    pickle.dump(ensemble, f)

# %% [markdown]
# ### Residual Plot

# %%
sns.residplot(y_ensemble_predicted.ravel() - y_test.ravel(), y_test.ravel(), lowess=True)
